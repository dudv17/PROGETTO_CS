# %% [markdown]
# # DOGS ADOPTIONS PROJECT

# %% [markdown]
# **Importing libraries**

# %%
import re
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_colwidth', 50)
pd.options.display.max_columns = 40
pd.options.display.max_rows = 700

# %% [markdown]
# **Importing the 'dogs', 'dog_travel' and 'NST_EST' dataframe:**

# %%
dogs = pd.read_csv("adoptions/dogs.csv")

# %%
dog_travel = pd.read_csv("adoptions/dogTravel.csv")

# %%
NST_EST = pd.read_csv("adoptions/NST-EST2021-POP.csv", header=None)
NST_EST.columns = ['state', 'population']

# %% [markdown]
# **Converts the values in 'population column' from strings to integers**

# %%
NST_EST['population'] = NST_EST['population'].str.replace('.', '', regex=False).astype(int)

#The str.replace() method replaces any dots in the population column with an empty string,
#and then the astype() method converts the resulting strings to integers

# %% [markdown]
# **Importing the 'states' dataset, which contains all the USA states and their abbreviation (this dataset will be used in exercise 5 and 9)**

# %%
states = pd.read_csv("adoptions/states.csv", sep=';')

states['zip_end'] = states['zip_end'].fillna(0)
states['zip_end'] = states['zip_end'].astype(int)

states['zip_start'] = states['zip_start'].fillna(0)
states['zip_start'] = states['zip_start'].astype(int)

states.head()
# Out:
#         state abbreviation  zip_start  zip_end
# 0     Alabama           AL      35004    36925
# 1      Alaska           AK      99501     9950
# 2     Arizona           AZ      85001    86556
# 3    Arkansas           AR      71601    72959
# 4  California           CA      90001    96162

# %% [markdown]
# # PRE-PROCESSING

# %% [markdown]
# **Cleaning the 'name' column in the 'dogs' dataframe**
#
# **In the following rows, column 'status' contains the dog name in a "dirty" form and also what should be contained in the 'description' column**

# %%
names_and_desc = dogs[dogs['status'] != 'adoptable']['name'] 
names_and_desc.head()
# Out:
# 644      Gunther :Gunny\",Meet handsome 3 year old Gunt...
# 5549     ANNABELLE \ANNIE\","You can fill out an adopti...
# 10888    PEPPER \Courtesy listing\","This is Pepper. He...
# 11983    COOPER \courtesy listing\","Cooper is 13 years...
# 12495    DAISY \courtesy listing\","•Basset Hound, fema...
# Name: name, dtype: object

# %% [markdown]
# **Isolate the names in "dirty" form in a separate list:**

# %%
dirty_names = []
for name_desc in names_and_desc:   #iterate through each element in 'names_and_desc'
    dirty_names.append(name_desc.split(sep=",")[0])   #split name and desctiption and append only the
dirty_names
# Out:
# ['Gunther :Gunny\\"',
#  'ANNABELLE \\ANNIE\\"',
#  'PEPPER \\Courtesy listing\\"',
#  'COOPER \\courtesy listing\\"',
#  'DAISY \\courtesy listing\\"',
#  'Elmo \\MoMo\\"',
#  'Bianca \\Pinky\\"',
#  '\\Baby Girl\\"',
#  'King Bert \\Bertie\\"',
#  'Maddie \\Cutie Patootie!\\"',
#  'Bucky \\Are u my hooman?\\"',
#  'CHLOE \\LITTLE RASCAL\\"',
#  'COZI H WILSON \\loves children',
#  'Gibson Edgar \\Gibbs\\"',
#  'PUPPIES \\Berries\\"',
#  'Leila \\COURTESY POST\\"',
#  'Eden \\In Training\\"',
#  'Coach Chris \\Mack\\"',
#  'Liberty \\Libby\\"',
#  'Samson \\Sam\\"',
#  'Sully \\Sullivan\\"',
#  'PERIWINKLE \\WINK\\"',
#  'Raymond \\Reddington\\"',
#  'Norma Rose \\ROSIE\\"',
#  'Markey \\Moose\\"',
#  'George \\Boy George\\"',
#  '\\Skipper\\"',
#  '\\Bella\\"',
#  '\\Cody\\"',
#  '\\Gracie\\"',
#  '\\Jameson\\"',
#  '\\Canelo\\"',
#  '\\Noni\\"']

# %% [markdown]
# There are two pattern in the diry names:
# 1. name \\\nickname-char\\\\"
# 2. \\\nickname-char\\\\"
#
# in the first case we want to isolate the name
#
# in the second case we isolate the nickname

# %%
nomi = []
for name in dirty_names:
    match = re.split(r'[:\\]', name)    #matches either a colon (:) or a backslash (\) and split 'name' where it is matched
                                        #stores the results in a list called 'match'            
    if match[0] == '':                  #pattern n° 2 -> the 'match' list contains only the nickname
        nomi.append(match[1].strip())   #remove leading or trailing spaces with 'strip()' and appending to the 'nomi' list
    else:                               #pattern n° 1 -> the 'match' list contains only the nickname
        nomi.append(match[0].strip()) 
dogs_clean = dogs.copy(deep=True)       #create a copy of the 'dogs' dataframe ('dogs_clean') that is completely 
                                        #indipendent from it (thanks to deep=True): if you modify 'dogs' this will
                                        # not affect 'dogs_clean'

dogs_clean.loc[dogs_clean['status'] != 'adoptable', 'name'] = nomi 
# ^ assign the cleaned names in the column 'name' of dogs_clean

dogs_clean[dogs_clean['status'] != 'adoptable']['name']
# Out:
# 644            Gunther
# 5549         ANNABELLE
# 10888           PEPPER
# 11983           COOPER
# 12495            DAISY
# 12600             Elmo
# 12613           Bianca
# 17619        Baby Girl
# 18611        King Bert
# 19747           Maddie
# 19845            Bucky
# 22161            CHLOE
# 22229    COZI H WILSON
# 29283     Gibson Edgar
# 30471          PUPPIES
# 31581            Leila
# 31888             Eden
# 33000      Coach Chris
# 33527          Liberty
# 34188           Samson
# 35065            Sully
# 44830       PERIWINKLE
# 53168          Raymond
# 53539       Norma Rose
# 55434           Markey
# 55467           George
# 55915          Skipper
# 55975            Bella
# 56013             Cody
# 56248           Gracie
# 56464          Jameson
# 56473           Canelo
# 56541             Noni
# Name: name, dtype: object

# %% [markdown]
# **Shift the columns corresponding to the previous names from 'status' to 'accessed' of one to the right**

# %%
dogs_clean.loc[dogs_clean['status'] != 'adoptable','status':'accessed'] = dogs_clean.loc[dogs_clean['status'] != 'adoptable','status':'accessed'].shift(1, axis=1)
dogs_clean.loc[dogs_clean['status'] != 'adoptable']
# Out:
#              id  org_id                                                url  \
# 644    41330726   NV173  https://www.petfinder.com/dog/gunther-gunny-41...
# 5549   38169117   AZ414  https://www.petfinder.com/dog/annabelle-annie-...
# 10888  45833989    NY98  https://www.petfinder.com/dog/pepper-courtesy-...
# 11983  45515547    NY98  https://www.petfinder.com/dog/cooper-courtesy-...
# 12495  45294115    NY98  https://www.petfinder.com/dog/daisy-courtesy-l...
# 12600  45229004  NY1436  https://www.petfinder.com/dog/elmo-momo-452290...
# 12613  45227052  NY1436  https://www.petfinder.com/dog/bianca-pinky-452...
# 17619  45569380  CA1209  https://www.petfinder.com/dog/baby-girl-455693...
# 18611  44694387   MD295  https://www.petfinder.com/dog/king-bert-bertie...
# 19747  36978896   VA127  https://www.petfinder.com/dog/maddie-cutie-pat...
# 19845  33218331   VA127  https://www.petfinder.com/dog/bucky-are-u-my-h...
# 22161  42092005   PA738  https://www.petfinder.com/dog/chloe-little-ras...
# 22229  39594038   PA562  https://www.petfinder.com/dog/cozi-h-wilson-lo...
# 29283  45895274   IL688  https://www.petfinder.com/dog/gibson-edgar-gib...
# 30471  45964719   IN694  https://www.petfinder.com/dog/puppies-berries-...
# 31581  44538917   OH907  https://www.petfinder.com/dog/leila-courtesy-p...
# 31888  41430442   OH907  https://www.petfinder.com/dog/eden-in-training...
# 33000  45907639   IN714  https://www.petfinder.com/dog/coach-chris-mack...
# 33527  45362806   OH852  https://www.petfinder.com/dog/liberty-libby-45...
# 34188  32590894   IN595  https://www.petfinder.com/dog/samson-sam-32590...
# 35065  31426754   LA256  https://www.petfinder.com/dog/sully-sullivan-3...
# 44830  46037827   NM133  https://www.petfinder.com/dog/periwinkle-wink-...
# 53168  44044071   TN669  https://www.petfinder.com/dog/raymond-reddingt...
# 53539  27521132   TN577  https://www.petfinder.com/dog/norma-rose-rosie...
# 55434  38473806   VA486  https://www.petfinder.com/dog/markey-moose-384...
# 55467  34101432   VA628  https://www.petfinder.com/dog/george-boy-georg...
# 55915  45958435   WA581  https://www.petfinder.com/dog/skipper-45958435...
# 55975  45927580   WA581  https://www.petfinder.com/dog/bella-45927580/w...
# 56013  45916348   WA581  https://www.petfinder.com/dog/cody-45916348/wa...
# 56248  45733027   WA581  https://www.petfinder.com/dog/gracie-45733027/...
# 56464  45413997   WA581  https://www.petfinder.com/dog/jameson-45413997...
# 56473  45406516   WA581  https://www.petfinder.com/dog/canelo-45406516/...
# 56541  45264615   WA581  https://www.petfinder.com/dog/noni-45264615/wa...
#
#       type.x species                   breed_primary  \
# 644      Dog     Dog             German Shepherd Dog
# 5549     Dog     Dog                           Boxer
# 10888    Dog     Dog                          Beagle
# 11983    Dog     Dog                     Mixed Breed
# 12495    Dog     Dog                    Basset Hound
# 12600    Dog     Dog                American Bulldog
# 12613    Dog     Dog                     Mixed Breed
# 17619    Dog     Dog                         Maltese
# 18611    Dog     Dog                     Fox Terrier
# 19747    Dog     Dog                Alaskan Malamute
# 19845    Dog     Dog                Alaskan Malamute
# 22161    Dog     Dog                Pit Bull Terrier
# 22229    Dog     Dog                Pit Bull Terrier
# 29283    Dog     Dog              Labrador Retriever
# 30471    Dog     Dog  American Staffordshire Terrier
# 31581    Dog     Dog             Australian Shepherd
# 31888    Dog     Dog                           Hound
# 33000    Dog     Dog                       Chihuahua
# 33527    Dog     Dog                      Pomeranian
# 34188    Dog     Dog                         Mastiff
# 35065    Dog     Dog                Pit Bull Terrier
# 44830    Dog     Dog             Australian Shepherd
# 53168    Dog     Dog  American Staffordshire Terrier
# 53539    Dog     Dog       Yellow Labrador Retriever
# 55434    Dog     Dog                           Hound
# 55467    Dog     Dog              Labrador Retriever
# 55915    Dog     Dog               Yorkshire Terrier
# 55975    Dog     Dog                       Chihuahua
# 56013    Dog     Dog                Golden Retriever
# 56248    Dog     Dog                        Papillon
# 56464    Dog     Dog                     Rat Terrier
# 56473    Dog     Dog                       Chihuahua
# 56541    Dog     Dog                       Chihuahua
#
#                       breed_secondary  breed_mixed  breed_unknown  \
# 644                               NaN        False          False
# 5549                 Pit Bull Terrier         True          False
# 10888                             NaN        False          False
# 11983                             NaN        False          False
# 12495                             NaN        False          False
# 12600                             NaN         True          False
# 12613                             NaN        False          False
# 17619                             NaN        False          False
# 18611                       Chihuahua         True          False
# 19747                             NaN        False          False
# 19845                  Siberian Husky         True          False
# 22161                         Pointer         True          False
# 22229                             NaN         True          False
# 29283                             NaN         True          False
# 30471                   Border Collie         True          False
# 31581                           Husky         True          False
# 31888                             NaN         True          False
# 33000                          Beagle         True          False
# 33527                             NaN        False          False
# 34188              Labrador Retriever         True          False
# 35065                             NaN        False          False
# 44830                         Spaniel         True          False
# 53168                             NaN         True          False
# 53539  American Staffordshire Terrier         True          False
# 55434                             NaN        False          False
# 55467                             NaN         True          False
# 55915                         Terrier         True          False
# 55975                             NaN        False          False
# 56013                         Terrier         True          False
# 56248   Cavalier King Charles Spaniel         True          False
# 56464                       Chihuahua         True          False
# 56473                         Terrier         True          False
# 56541                         Terrier         True          False
#
#                           color_primary                   color_secondary  \
# 644                                 NaN                               NaN
# 5549                              Black                     White / Cream
# 10888                               NaN                               NaN
# 11983                               NaN                               NaN
# 12495                 Brown / Chocolate                     White / Cream
# 12600                               NaN                               NaN
# 12613                     White / Cream                               NaN
# 17619                     White / Cream                               NaN
# 18611                           Bicolor                               NaN
# 19747                           Bicolor                               NaN
# 19845              Gray / Blue / Silver                               NaN
# 22161                             Black                     White / Cream
# 22229                               NaN                               NaN
# 29283                 Brown / Chocolate                               NaN
# 30471                             Black                     White / Cream
# 31581  Tricolor (Brown, Black, & White)                               NaN
# 31888                     White / Cream       Yellow / Tan / Blond / Fawn
# 33000       Yellow / Tan / Blond / Fawn                               NaN
# 33527                               NaN                               NaN
# 34188                             Black                               NaN
# 35065                             Black                               NaN
# 44830                 Brown / Chocolate                     White / Cream
# 53168           Red / Chestnut / Orange                               NaN
# 53539       Yellow / Tan / Blond / Fawn                               NaN
# 55434                     White / Cream       Yellow / Tan / Blond / Fawn
# 55467       Yellow / Tan / Blond / Fawn                     White / Cream
# 55915  Tricolor (Brown, Black, & White)                     White / Cream
# 55975                     White / Cream       Yellow / Tan / Blond / Fawn
# 56013                           Bicolor  Tricolor (Brown, Black, & White)
# 56248                            Golden           Red / Chestnut / Orange
# 56464  Tricolor (Brown, Black, & White)                     White / Cream
# 56473                           Bicolor                            Golden
# 56541                             Black                     White / Cream
#
#                     color_tertiary     age     sex         size    coat  \
# 644                            NaN   Young    Male        Large     NaN
# 5549                           NaN   Adult  Female        Large   Short
# 10888                          NaN  Senior    Male       Medium   Short
# 11983                          NaN  Senior    Male       Medium   Short
# 12495                          NaN  Senior  Female       Medium   Short
# 12600                          NaN  Senior    Male        Large   Short
# 12613                          NaN  Senior  Female       Medium   Short
# 17619                          NaN  Senior  Female        Small   Short
# 18611                          NaN   Young    Male        Small   Short
# 19747                          NaN   Adult  Female        Large     NaN
# 19845                          NaN   Adult    Male        Large  Medium
# 22161                          NaN   Adult  Female       Medium   Short
# 22229                          NaN   Young  Female       Medium   Short
# 29283                          NaN   Young    Male        Large   Short
# 30471                          NaN    Baby  Female       Medium   Short
# 31581                          NaN   Adult  Female       Medium   Short
# 31888                          NaN   Adult  Female       Medium   Short
# 33000                          NaN   Adult    Male        Small   Short
# 33527                          NaN   Adult  Female        Small    Long
# 34188                          NaN   Adult    Male  Extra Large     NaN
# 35065                          NaN   Young    Male       Medium   Short
# 44830                          NaN   Adult  Female       Medium  Medium
# 53168                          NaN   Adult    Male       Medium  Medium
# 53539                          NaN   Adult  Female        Large   Short
# 55434                          NaN   Adult    Male        Large   Short
# 55467                          NaN   Young    Male       Medium   Short
# 55915  Yellow / Tan / Blond / Fawn   Young    Male        Small  Medium
# 55975                          NaN   Adult  Female        Small   Short
# 56013                          NaN   Adult    Male       Medium   Short
# 56248                          NaN   Adult  Female        Small  Medium
# 56464                          NaN   Young    Male        Small     NaN
# 56473                          NaN   Adult    Male        Small   Short
# 56541                          NaN   Adult  Female        Small     NaN
#
#        fixed  house_trained  declawed  special_needs  shots_current  \
# 644    False          False       NaN          False          False
# 5549    True           True       NaN          False           True
# 10888   True           True       NaN          False           True
# 11983   True           True       NaN          False           True
# 12495   True           True       NaN          False           True
# 12600   True           True       NaN          False           True
# 12613   True           True       NaN          False           True
# 17619   True           True       NaN          False           True
# 18611   True          False       NaN          False           True
# 19747   True           True       NaN          False           True
# 19845   True           True       NaN          False           True
# 22161   True          False       NaN          False           True
# 22229   True           True       NaN          False           True
# 29283   True           True       NaN          False           True
# 30471  False          False       NaN          False           True
# 31581   True           True       NaN          False           True
# 31888   True          False       NaN          False           True
# 33000   True           True       NaN          False           True
# 33527   True          False       NaN          False           True
# 34188  False          False       NaN          False          False
# 35065   True           True       NaN          False           True
# 44830   True           True       NaN          False           True
# 53168   True          False       NaN          False          False
# 53539   True           True       NaN          False           True
# 55434  False           True       NaN          False           True
# 55467   True          False       NaN          False           True
# 55915   True          False       NaN          False           True
# 55975   True           True       NaN           True           True
# 56013   True           True       NaN          False           True
# 56248   True           True       NaN          False           True
# 56464   True          False       NaN          False           True
# 56473   True          False       NaN          False           True
# 56541   True           True       NaN          False           True
#
#       env_children env_dogs env_cats           name status  \
# 644            NaN      NaN      NaN        Gunther   None
# 5549           NaN      NaN    False      ANNABELLE   None
# 10888         True     True     True         PEPPER   None
# 11983          NaN      NaN    False         COOPER   None
# 12495        False    False      NaN          DAISY   None
# 12600         True     True      NaN           Elmo   None
# 12613         True     True      NaN         Bianca   None
# 17619         True     True      NaN      Baby Girl   None
# 18611        False      NaN    False      King Bert   None
# 19747          NaN      NaN    False         Maddie   None
# 19845          NaN      NaN    False          Bucky   None
# 22161         True     True      NaN          CHLOE   None
# 22229         True     True      NaN  COZI H WILSON   None
# 29283         True     True    False   Gibson Edgar   None
# 30471         True     True      NaN        PUPPIES   None
# 31581          NaN      NaN      NaN          Leila   None
# 31888          NaN    False      NaN           Eden   None
# 33000         True     True      NaN    Coach Chris   None
# 33527        False     True     True        Liberty   None
# 34188          NaN      NaN      NaN         Samson   None
# 35065          NaN      NaN      NaN          Sully   None
# 44830         True     True      NaN     PERIWINKLE   None
# 53168         True      NaN    False        Raymond   None
# 53539         True    False    False     Norma Rose   None
# 55434         True     True      NaN         Markey   None
# 55467          NaN      NaN      NaN         George   None
# 55915          NaN     True     True        Skipper   None
# 55975        False     True      NaN          Bella   None
# 56013         True     True      NaN           Cody   None
# 56248          NaN     True      NaN         Gracie   None
# 56464        False     True     True        Jameson   None
# 56473        False     True      NaN         Canelo   None
# 56541        False     True    False           Noni   None
#
#                          posted    contact_city contact_state contact_zip  \
# 644    2018-04-05T05:18:31+0000       Las Vegas            NV       89146
# 5549   2017-05-26T21:43:16+0000        Chandler            AZ       85249
# 10888  2019-09-01T15:12:06+0000          Albany            NY       12220
# 11983  2019-08-06T12:15:58+0000          Albany            NY       12220
# 12495  2019-07-18T14:20:58+0000          Albany            NY       12220
# 12600  2019-07-11T20:34:42+0000      Saugerties            NY       12477
# 12613  2019-07-11T14:16:38+0000      Saugerties            NY       12477
# 17619  2019-08-10T16:00:35+0000         Bristow            VA       20136
# 18611  2019-05-14T21:09:27+0000   Silver Spring            MD       20905
# 19747  2016-12-15T13:33:43+0000      Gettysburg            PA       17325
# 19845  2015-09-07T12:57:27+0000      Gettysburg            PA       17325
# 22161  2018-07-05T00:55:08+0000           Media            PA       19063
# 22229  2017-10-07T23:48:20+0000    Feasterville            PA       19053
# 29283  2019-09-07T04:09:12+0000           Paris            IL       61944
# 30471  2019-09-13T19:39:28+0000     Mooresville            IN       46158
# 31581  2019-04-25T01:56:52+0000            Ross            OH       45061
# 31888  2018-04-18T13:45:46+0000            Ross            OH       45061
# 33000  2019-09-08T18:21:21+0000  Jeffersonville            IN       47131
# 33527  2019-07-25T19:53:21+0000      Cincinnati            OH       45249
# 34188  2015-06-29T23:58:09+0000           Paoli            IN       47454
# 35065  2015-02-07T13:06:43+0000    lake charles            LA       70601
# 44830  2019-09-20T01:50:51+0000     Albuquerque            NM       87108
# 53168  2019-02-18T12:02:48+0000      Cookeville            TN       38506
# 53539  2013-10-10T13:57:39+0000       Nashville            TN       37189
# 55434  2017-06-16T18:44:33+0000        Rustburg            VA       24588
# 55467  2015-12-25T12:28:30+0000      Midlothian            VA       23112
# 55915  2019-09-13T06:08:17+0000         Seattle            WA       98106
# 55975  2019-09-10T16:43:35+0000         Seattle            WA       98106
# 56013  2019-09-09T17:05:17+0000         Seattle            WA       98106
# 56248  2019-08-24T16:32:31+0000         Seattle            WA       98106
# 56464  2019-07-31T16:21:07+0000         Seattle            WA       98106
# 56473  2019-07-29T21:50:16+0000         Seattle            WA       98106
# 56541  2019-07-15T16:57:05+0000         Seattle            WA       98106
#
#       contact_country stateQ    accessed type.y  \
# 644                US  89009  2019-09-20    Dog
# 5549               US     AZ  2019-09-20    Dog
# 10888              US     CT  2019-09-20    Dog
# 11983              US     CT  2019-09-20    Dog
# 12495              US     CT  2019-09-20    Dog
# 12600              US     CT  2019-09-20    Dog
# 12613              US     CT  2019-09-20    Dog
# 17619              US     DC  2019-09-20    Dog
# 18611              US     DC  2019-09-20    Dog
# 19747              US     DC  2019-09-20    Dog
# 19845              US     DC  2019-09-20    Dog
# 22161              US     DE  2019-09-20    Dog
# 22229              US     DE  2019-09-20    Dog
# 29283              US     IL  2019-09-20    Dog
# 30471              US     IN  2019-09-20    Dog
# 31581              US     IN  2019-09-20    Dog
# 31888              US     IN  2019-09-20    Dog
# 33000              US     KY  2019-09-20    Dog
# 33527              US     KY  2019-09-20    Dog
# 34188              US     KY  2019-09-20    Dog
# 35065              US     LA  2019-09-20    Dog
# 44830              US     NM  2019-09-20    Dog
# 53168              US     TN  2019-09-20    Dog
# 53539              US     TN  2019-09-20    Dog
# 55434              US     VA  2019-09-20    Dog
# 55467              US     VA  2019-09-20    Dog
# 55915              US     WA  2019-09-20    Dog
# 55975              US     WA  2019-09-20    Dog
# 56013              US     WA  2019-09-20    Dog
# 56248              US     WA  2019-09-20    Dog
# 56464              US     WA  2019-09-20    Dog
# 56473              US     WA  2019-09-20    Dog
# 56541              US     WA  2019-09-20    Dog
#
#                                              description  stay_duration  \
# 644    Meet handsome 3 year old Gunther. Gunther came...            108
# 5549   You can fill out an adoption application onlin...             80
# 10888  This is Pepper. He is a 15 year old tri-color ...             86
# 11983  Cooper is 13 years old, but according to a ver...            105
# 12495  â¢Basset Hound, female, â¢10 years \n\nDelig...             57
# 12600  Hello i'm MoMo or Elmo , 7 year old, mixed bre...             73
# 12613  Hello I'm Bianca, a female, 7 year old mixed b...            107
# 17619  This 10-year young senior is very sweet and lo...             76
# 18611  \"Bertie\" came to us from the shelter.  He wa...             61
# 19747  Maddie is our little Miss Cutie Patootie! She ...            119
# 19845  Born in August 2014, Bucky has a great sense o...             98
# 22161                   Meet Chloe our \"Little Rascal.\            113
# 22229  01.04.19\nHi Folks! Iâm Cozi and Iâm so gl...             88
# 29283  Gibson Edgar is a 12 month old male Lab mix th...             74
# 30471  11 Berry Pups\nIndividual pics will be done.  ...            127
# 31581  THIS IS A COURTESY POST (this means that any a...             92
# 31888  Eden is estimated 3 years old and weighs 40 lb...             97
# 33000  Mack is a 2 year old, 13 pound furry chihuahua...            101
# 33527  Liberty came to us on the 3rd of July - she ha...             65
# 34188  DUE TO PROBLEMS WITH THE CURRENT PETFINDER UPD...            116
# 35065  Hi my name is Sully! I get along with most dog...            122
# 44830  We take the time to post pertinent information...             85
# 53168  Red  is a 4-5 yr old Staffey mix that is a wig...             88
# 53539  Robyn's Nest Animal Rescue & SanctuaryNashvill...             93
# 55434  Markey \"Moose\" first came to us after being ...             78
# 55467  Contact dojennings@Comcast.net or Debbie Jenni...            115
# 55915  For a quicker response please submit a online ...            102
# 55975  Meet \"Bella\" She is a adorable and 7 pounds ...            102
# 56013  *Please apply online at www.6dogrees.com to ge...             92
# 56248  Meet \"Gracie\" a very beautiful 11 pound,fema...             82
# 56464  Meet \"Jameson\" He is a very handsome 9 pound...            108
# 56473  Meet Canelo  a adorable  small, tan very sweet...             94
# 56541  Meet \"Noni\" She is a Black and white smooth ...             77
#
#        stay_cost
# 644       256.88
# 5549      130.77
# 10888     180.70
# 11983     400.82
# 12495      82.61
# 12600     136.30
# 12613     231.31
# 17619     263.63
# 18611     158.84
# 19747     431.66
# 19845     346.67
# 22161     279.59
# 22229     360.84
# 29283     121.56
# 30471     429.87
# 31581     188.49
# 31888     238.60
# 33000     478.36
# 33527     185.05
# 34188     413.96
# 35065     204.63
# 44830     296.75
# 53168     230.12
# 53539     300.50
# 55434      71.15
# 55467     320.23
# 55915     338.18
# 55975     407.51
# 56013     164.55
# 56248     168.54
# 56464     297.27
# 56473     312.10
# 56541     290.16

# %%
dogs_clean.loc[17610:17630,'status':'accessed']
# Out:
#           status                    posted    contact_city contact_state  \
# 17610  adoptable  2019-08-10T22:33:34+0000    Chambersburg            PA
# 17611  adoptable  2019-08-10T20:56:53+0000      Pennsville            NJ
# 17612  adoptable  2019-08-10T19:50:26+0000      Hagerstown            MD
# 17613  adoptable  2019-08-10T19:49:23+0000     Springfield            VA
# 17614  adoptable  2019-08-10T19:31:25+0000      Hagerstown            MD
# 17615  adoptable  2019-08-10T17:47:16+0000         Paw Paw            WV
# 17616  adoptable  2019-08-10T16:46:30+0000         Bristow            VA
# 17617  adoptable  2019-08-10T16:21:20+0000       Baltimore            MD
# 17618  adoptable  2019-08-10T16:08:13+0000       Baltimore            MD
# 17619       None  2019-08-10T16:00:35+0000         Bristow            VA
# 17620  adoptable  2019-08-10T15:47:38+0000        Newville            PA
# 17621  adoptable  2019-08-10T15:17:25+0000         Bristow            VA
# 17622  adoptable  2019-08-10T14:50:35+0000  Fredericksburg            VA
# 17623  adoptable  2019-08-10T14:42:47+0000  Fredericksburg            VA
# 17624  adoptable  2019-08-10T14:05:27+0000        Richmond            VA
# 17625  adoptable  2019-08-10T14:02:54+0000        Richmond            VA
# 17626  adoptable  2019-08-10T13:18:21+0000     Westminster            MD
# 17627  adoptable  2019-08-10T13:18:20+0000     Westminster            MD
# 17628  adoptable  2019-08-10T13:06:43+0000       Delaplane            VA
# 17629  adoptable  2019-08-10T13:06:43+0000       Delaplane            VA
# 17630  adoptable  2019-08-10T13:06:43+0000       Delaplane            VA
#
#       contact_zip contact_country stateQ    accessed
# 17610       17201              US     DC  2019-09-20
# 17611       08070              US     DC  2019-09-20
# 17612       21740              US     DC  2019-09-20
# 17613       22153              US     DC  2019-09-20
# 17614       21740              US     DC  2019-09-20
# 17615       25434              US     DC  2019-09-20
# 17616       20136              US     DC  2019-09-20
# 17617       21224              US     DC  2019-09-20
# 17618       21224              US     DC  2019-09-20
# 17619       20136              US     DC  2019-09-20
# 17620       17241              US     DC  2019-09-20
# 17621       20136              US     DC  2019-09-20
# 17622       22408              US     DC  2019-09-20
# 17623       22408              US     DC  2019-09-20
# 17624       23228              US     DC  2019-09-20
# 17625       23228              US     DC  2019-09-20
# 17626       21158              US     DC  2019-09-20
# 17627       21158              US     DC  2019-09-20
# 17628       20144              US     DC  2019-09-20
# 17629       20144              US     DC  2019-09-20
# 17630       20144              US     DC  2019-09-20

# %% [markdown]
# # 1. Extract all dogs with status that is not adoptable

# %% [markdown]
# **Dataset before cleaning:**

# %%
dogs[dogs['status'] != 'adoptable'][['id', 'name', 'status']].head()
# Out:
#              id                                               name  \
# 644    41330726  Gunther :Gunny\",Meet handsome 3 year old Gunt...
# 5549   38169117  ANNABELLE \ANNIE\","You can fill out an adopti...
# 10888  45833989  PEPPER \Courtesy listing\","This is Pepper. He...
# 11983  45515547  COOPER \courtesy listing\","Cooper is 13 years...
# 12495  45294115  DAISY \courtesy listing\","•Basset Hound, fema...
#
#                          status
# 644    2018-04-05T05:18:31+0000
# 5549   2017-05-26T21:43:16+0000
# 10888  2019-09-01T15:12:06+0000
# 11983  2019-08-06T12:15:58+0000
# 12495  2019-07-18T14:20:58+0000

# %% [markdown]
# **Cleaned dataset:**

# %%
not_ad_dogs = dogs_clean[dogs_clean['status'] != 'adoptable'][['id', 'name', 'status']]
not_ad_dogs.head()
# Out:
#              id       name status
# 644    41330726    Gunther   None
# 5549   38169117  ANNABELLE   None
# 10888  45833989     PEPPER   None
# 11983  45515547     COOPER   None
# 12495  45294115      DAISY   None

# %% [markdown]
# # 2. For each (primary) breed, determine the number of dogs

# %%
breed_counts = dogs.groupby('breed_primary').count()[['id']].rename(columns={'id':'counts'})#.reset_index()[['breed_primary','counts']]
breed_counts
# Out:
#                                           counts
# breed_primary
# Affenpinscher                                 17
# Afghan Hound                                   4
# Airedale Terrier                              19
# Akbash                                         3
# Akita                                        181
# Alaskan Malamute                              72
# American Bulldog                            1134
# American Eskimo Dog                           43
# American Foxhound                             17
# American Hairless Terrier                      4
# American Staffordshire Terrier              1862
# Anatolian Shepherd                           118
# Australian Cattle Dog / Blue Heeler          973
# Australian Kelpie                             43
# Australian Shepherd                          696
# Australian Terrier                            15
# Basenji                                       54
# Basset Hound                                 241
# Beagle                                      1539
# Bearded Collie                                 6
# Beauceron                                      4
# Belgian Shepherd / Laekenois                   1
# Belgian Shepherd / Malinois                   94
# Belgian Shepherd / Sheepdog                    3
# Belgian Shepherd / Tervuren                    2
# Bernese Mountain Dog                          20
# Bichon Frise                                  82
# Black Labrador Retriever                     545
# Black Mouth Cur                              201
# Black and Tan Coonhound                       88
# Bloodhound                                    54
# Blue Lacy                                     13
# Bluetick Coonhound                            92
# Boerboel                                       8
# Bolognese                                      1
# Border Collie                                817
# Border Terrier                                28
# Borzoi                                         6
# Boston Terrier                               149
# Bouvier des Flandres                           1
# Boxer                                       2050
# Boykin Spaniel                                 1
# Briard                                         1
# Brittany Spaniel                              31
# Brussels Griffon                              24
# Bull Terrier                                 176
# Bullmastiff                                   55
# Cairn Terrier                                 91
# Canaan Dog                                    17
# Cane Corso                                    83
# Cardigan Welsh Corgi                          26
# Carolina Dog                                  61
# Catahoula Leopard Dog                        488
# Cattle Dog                                   444
# Caucasian Sheepdog / Caucasian Ovtcharka       3
# Cavalier King Charles Spaniel                 23
# Chesapeake Bay Retriever                      23
# Chihuahua                                   3766
# Chinese Crested Dog                           18
# Chinese Foo Dog                                1
# Chinook                                        1
# Chocolate Labrador Retriever                 155
# Chow Chow                                    165
# Clumber Spaniel                                4
# Cockapoo                                      17
# Cocker Spaniel                               209
# Collie                                       236
# Coonhound                                    286
# Corgi                                        128
# Coton de Tulear                                2
# Curly-Coated Retriever                         2
# Dachshund                                    853
# Dalmatian                                     77
# Doberman Pinscher                            267
# Dogo Argentino                                34
# Dogue de Bordeaux                             22
# Dutch Shepherd                                63
# English Bulldog                              177
# English Cocker Spaniel                         2
# English Coonhound                             30
# English Foxhound                               4
# English Pointer                               90
# English Setter                                28
# English Shepherd                              20
# English Springer Spaniel                      35
# Entlebucher                                    2
# Eskimo Dog                                     8
# Feist                                        139
# Field Spaniel                                  1
# Fila Brasileiro                                1
# Finnish Spitz                                  5
# Flat-Coated Retriever                         43
# Fox Terrier                                   40
# Foxhound                                     100
# French Bulldog                                46
# Galgo Spanish Greyhound                        8
# German Pinscher                                7
# German Shepherd Dog                         2122
# German Shorthaired Pointer                    88
# German Spitz                                   2
# German Wirehaired Pointer                     10
# Giant Schnauzer                                6
# Golden Retriever                             203
# Gordon Setter                                  2
# Great Dane                                   334
# Great Pyrenees                               481
# Greater Swiss Mountain Dog                     7
# Greyhound                                    306
# Harrier                                       14
# Havanese                                      24
# Hound                                       2282
# Husky                                        567
# Ibizan Hound                                   5
# Irish Setter                                   8
# Irish Terrier                                 17
# Irish Wolfhound                               17
# Italian Greyhound                             66
# Jack Russell Terrier                         637
# Japanese Chin                                 15
# Jindo                                         46
# Kai Dog                                        1
# Keeshond                                       4
# Kuvasz                                         1
# Kyi Leo                                        2
# Labrador Retriever                          7198
# Lakeland Terrier                               5
# Lancashire Heeler                              4
# Leonberger                                     1
# Lhasa Apso                                    60
# Maltese                                      183
# Manchester Terrier                            39
# Maremma Sheepdog                               4
# Mastiff                                      301
# McNab                                          5
# Miniature Dachshund                            3
# Miniature Pinscher                           317
# Miniature Poodle                              12
# Miniature Schnauzer                           26
# Mixed Breed                                 3242
# Mountain Cur                                 168
# Mountain Dog                                  16
# Neapolitan Mastiff                             9
# Newfoundland Dog                              26
# Norfolk Terrier                                5
# Norwegian Buhund                               2
# Norwegian Elkhound                             6
# Norwich Terrier                                6
# Nova Scotia Duck Tolling Retriever             5
# Old English Sheepdog                           1
# Otterhound                                     2
# Papillon                                      59
# Parson Russell Terrier                        70
# Patterdale Terrier / Fell Terrier             16
# Pekingese                                     76
# Pembroke Welsh Corgi                           9
# Petit Basset Griffon Vendeen                  12
# Pharaoh Hound                                 11
# Pit Bull Terrier                            7890
# Plott Hound                                  265
# Pointer                                      367
# Pomeranian                                   252
# Poodle                                       304
# Portuguese Podengo                             4
# Presa Canario                                 27
# Pug                                          255
# Rat Terrier                                  338
# Redbone Coonhound                            104
# Retriever                                    538
# Rhodesian Ridgeback                           74
# Rottweiler                                   533
# Rough Collie                                   6
# Saint Bernard                                102
# Saluki                                        19
# Samoyed                                        8
# Schipperke                                    22
# Schnauzer                                    200
# Scottish Terrier                              13
# Setter                                        10
# Shar-Pei                                     249
# Sheep Dog                                      3
# Shepherd                                    1972
# Shetland Sheepdog / Sheltie                   54
# Shiba Inu                                     60
# Shih Tzu                                     421
# Siberian Husky                               439
# Silky Terrier                                 15
# Skye Terrier                                   1
# Smooth Collie                                  8
# Smooth Fox Terrier                             4
# Spaniel                                      148
# Spinone Italiano                               1
# Spitz                                         34
# Staffordshire Bull Terrier                   390
# Standard Poodle                               47
# Standard Schnauzer                            14
# Terrier                                     2641
# Thai Ridgeback                                 3
# Tibetan Mastiff                               10
# Tibetan Spaniel                                9
# Tibetan Terrier                                3
# Tosa Inu                                       1
# Toy Fox Terrier                               26
# Treeing Walker Coonhound                     258
# Vizsla                                        60
# Weimaraner                                   126
# West Highland White Terrier / Westie          19
# Wheaten Terrier                               19
# Whippet                                       83
# White German Shepherd                         17
# Wire Fox Terrier                              15
# Wirehaired Dachshund                           4
# Wirehaired Pointing Griffon                    1
# Wirehaired Terrier                            60
# Xoloitzcuintli / Mexican Hairless             11
# Yellow Labrador Retriever                    158
# Yorkshire Terrier                            360

# %% [markdown]
# # 3. For each (primary) breed, determine the ratio between the number of dogs of Mixed Breed and those not of Mixed Breed. Hint: look at the secondary_breed

# %%
dogs_clean.head()
# Out:
#          id org_id                                                url type.x  \
# 0  46042150  NV163  https://www.petfinder.com/dog/harley-46042150/...    Dog
# 1  46042002  NV163  https://www.petfinder.com/dog/biggie-46042002/...    Dog
# 2  46040898   NV99  https://www.petfinder.com/dog/ziggy-46040898/n...    Dog
# 3  46039877  NV202  https://www.petfinder.com/dog/gypsy-46039877/n...    Dog
# 4  46039306  NV184  https://www.petfinder.com/dog/theo-46039306/nv...    Dog
#
#   species                   breed_primary breed_secondary  breed_mixed  \
# 0     Dog  American Staffordshire Terrier     Mixed Breed         True
# 1     Dog                Pit Bull Terrier     Mixed Breed         True
# 2     Dog                        Shepherd             NaN        False
# 3     Dog             German Shepherd Dog             NaN        False
# 4     Dog                       Dachshund             NaN        False
#
#    breed_unknown      color_primary              color_secondary  \
# 0          False      White / Cream  Yellow / Tan / Blond / Fawn
# 1          False  Brown / Chocolate                White / Cream
# 2          False            Brindle                          NaN
# 3          False                NaN                          NaN
# 4          False                NaN                          NaN
#
#   color_tertiary     age     sex    size   coat  fixed  house_trained  \
# 0            NaN  Senior    Male  Medium  Short   True           True
# 1            NaN   Adult    Male   Large  Short   True           True
# 2            NaN   Adult    Male   Large  Short   True          False
# 3            NaN    Baby  Female   Large    NaN  False          False
# 4            NaN   Young    Male   Small   Long   True          False
#
#    declawed  special_needs  shots_current env_children env_dogs env_cats  \
# 0       NaN          False           True          NaN      NaN      NaN
# 1       NaN          False           True          NaN      NaN      NaN
# 2       NaN          False           True          NaN      NaN      NaN
# 3       NaN          False          False          NaN      NaN      NaN
# 4       NaN          False           True         True     True     True
#
#      name     status                    posted contact_city contact_state  \
# 0  HARLEY  adoptable  2019-09-20T16:37:59+0000    Las Vegas            NV
# 1  BIGGIE  adoptable  2019-09-20T16:24:57+0000    Las Vegas            NV
# 2   Ziggy  adoptable  2019-09-20T14:10:11+0000     Mesquite            NV
# 3   Gypsy  adoptable  2019-09-20T10:08:22+0000      Pahrump            NV
# 4    Theo  adoptable  2019-09-20T06:48:30+0000    Henderson            NV
#
#   contact_zip contact_country stateQ    accessed type.y  \
# 0       89147              US  89009  2019-09-20    Dog
# 1       89147              US  89009  2019-09-20    Dog
# 2       89027              US  89009  2019-09-20    Dog
# 3       89048              US  89009  2019-09-20    Dog
# 4       89052              US  89009  2019-09-20    Dog
#
#                                          description  stay_duration  stay_cost
# 0  Harley is not sure how he wound up at shelter ...             70     124.81
# 1  6 year old Biggie has lost his home and really...             49     122.07
# 2  Approx 2 years old.\n Did I catch your eye? I ...             87     281.51
# 3                                                NaN             62     145.83
# 4  Theo is a friendly dachshund mix who gets alon...             93     241.09

# %% [markdown]
# **METHOD 1:**
#
# **Considering the 'breed_secondary' column: if it contains the text 'Mixed Breed' it means that the dog is of mixed breed, otherwise it is not**

# %% [markdown]
# **Selecting the 'Mixed Breed' dogs**:

# %%
mixed_for_breed = dogs_clean[dogs_clean['breed_secondary'] == 'Mixed Breed'].groupby('breed_primary', as_index=False).count()
mixed_for_breed['n_mixed'] = mixed_for_breed['id']
mixed_for_breed = mixed_for_breed[['breed_primary', 'n_mixed']]
mixed_for_breed.head()
# Out:
#       breed_primary  n_mixed
# 0     Affenpinscher        1
# 1  Airedale Terrier        1
# 2             Akita        6
# 3  Alaskan Malamute        4
# 4  American Bulldog      106

# %% [markdown]
# **Selecting the 'Not of Mixed Breed' dogs**:

# %%
not_mixed_for_breed = dogs_clean[dogs_clean['breed_secondary'] != 'Mixed Breed'].groupby('breed_primary', as_index=False).count()
not_mixed_for_breed['n_not_mixed'] = not_mixed_for_breed['id']
not_mixed_for_breed = not_mixed_for_breed[['breed_primary', 'n_not_mixed']]
not_mixed_for_breed
# Out:
#                                 breed_primary  n_not_mixed
# 0                               Affenpinscher           16
# 1                                Afghan Hound            4
# 2                            Airedale Terrier           18
# 3                                      Akbash            3
# 4                                       Akita          175
# 5                            Alaskan Malamute           68
# 6                            American Bulldog         1028
# 7                         American Eskimo Dog           41
# 8                           American Foxhound           17
# 9                   American Hairless Terrier            2
# 10             American Staffordshire Terrier         1752
# 11                         Anatolian Shepherd          109
# 12        Australian Cattle Dog / Blue Heeler          901
# 13                          Australian Kelpie           34
# 14                        Australian Shepherd          672
# 15                         Australian Terrier           15
# 16                                    Basenji           50
# 17                               Basset Hound          227
# 18                                     Beagle         1459
# 19                             Bearded Collie            6
# 20                                  Beauceron            4
# 21               Belgian Shepherd / Laekenois            1
# 22                Belgian Shepherd / Malinois           87
# 23                Belgian Shepherd / Sheepdog            3
# 24                Belgian Shepherd / Tervuren            2
# 25                       Bernese Mountain Dog           19
# 26                               Bichon Frise           80
# 27                   Black Labrador Retriever          532
# 28                            Black Mouth Cur          182
# 29                    Black and Tan Coonhound           81
# 30                                 Bloodhound           50
# 31                                  Blue Lacy           13
# 32                         Bluetick Coonhound           88
# 33                                   Boerboel            8
# 34                                  Bolognese            1
# 35                              Border Collie          767
# 36                             Border Terrier           25
# 37                                     Borzoi            5
# 38                             Boston Terrier          142
# 39                       Bouvier des Flandres            1
# 40                                      Boxer         1907
# 41                             Boykin Spaniel            1
# 42                                     Briard            1
# 43                           Brittany Spaniel           31
# 44                           Brussels Griffon           23
# 45                               Bull Terrier          166
# 46                                Bullmastiff           52
# 47                              Cairn Terrier           85
# 48                                 Canaan Dog           17
# 49                                 Cane Corso           78
# 50                       Cardigan Welsh Corgi           21
# 51                               Carolina Dog           57
# 52                      Catahoula Leopard Dog          458
# 53                                 Cattle Dog          406
# 54   Caucasian Sheepdog / Caucasian Ovtcharka            3
# 55              Cavalier King Charles Spaniel           23
# 56                   Chesapeake Bay Retriever           22
# 57                                  Chihuahua         3576
# 58                        Chinese Crested Dog           18
# 59                            Chinese Foo Dog            1
# 60                                    Chinook            1
# 61               Chocolate Labrador Retriever          154
# 62                                  Chow Chow          145
# 63                            Clumber Spaniel            4
# 64                                   Cockapoo           17
# 65                             Cocker Spaniel          206
# 66                                     Collie          224
# 67                                  Coonhound          275
# 68                                      Corgi          124
# 69                            Coton de Tulear            2
# 70                     Curly-Coated Retriever            2
# 71                                  Dachshund          817
# 72                                  Dalmatian           72
# 73                          Doberman Pinscher          256
# 74                             Dogo Argentino           34
# 75                          Dogue de Bordeaux           18
# 76                             Dutch Shepherd           60
# 77                            English Bulldog          172
# 78                     English Cocker Spaniel            2
# 79                          English Coonhound           25
# 80                           English Foxhound            4
# 81                            English Pointer           89
# 82                             English Setter           28
# 83                           English Shepherd           18
# 84                   English Springer Spaniel           35
# 85                                Entlebucher            1
# 86                                 Eskimo Dog            8
# 87                                      Feist          134
# 88                              Field Spaniel            1
# 89                            Fila Brasileiro            1
# 90                              Finnish Spitz            5
# 91                      Flat-Coated Retriever           42
# 92                                Fox Terrier           36
# 93                                   Foxhound           96
# 94                             French Bulldog           45
# 95                    Galgo Spanish Greyhound            8
# 96                            German Pinscher            6
# 97                        German Shepherd Dog         1933
# 98                 German Shorthaired Pointer           83
# 99                               German Spitz            2
# 100                 German Wirehaired Pointer            8
# 101                           Giant Schnauzer            6
# 102                          Golden Retriever          197
# 103                             Gordon Setter            1
# 104                                Great Dane          329
# 105                            Great Pyrenees          470
# 106                Greater Swiss Mountain Dog            7
# 107                                 Greyhound          300
# 108                                   Harrier           14
# 109                                  Havanese           23
# 110                                     Hound         2093
# 111                                     Husky          536
# 112                              Ibizan Hound            5
# 113                              Irish Setter            8
# 114                             Irish Terrier           16
# 115                           Irish Wolfhound           16
# 116                         Italian Greyhound           63
# 117                      Jack Russell Terrier          632
# 118                             Japanese Chin           15
# 119                                     Jindo           46
# 120                                   Kai Dog            1
# 121                                  Keeshond            4
# 122                                    Kuvasz            1
# 123                                   Kyi Leo            2
# 124                        Labrador Retriever         6582
# 125                          Lakeland Terrier            5
# 126                         Lancashire Heeler            3
# 127                                Leonberger            1
# 128                                Lhasa Apso           58
# 129                                   Maltese          174
# 130                        Manchester Terrier           35
# 131                          Maremma Sheepdog            4
# 132                                   Mastiff          275
# 133                                     McNab            5
# 134                       Miniature Dachshund            2
# 135                        Miniature Pinscher          289
# 136                          Miniature Poodle           12
# 137                       Miniature Schnauzer           24
# 138                               Mixed Breed         3242
# 139                              Mountain Cur          162
# 140                              Mountain Dog           16
# 141                        Neapolitan Mastiff            9
# 142                          Newfoundland Dog           25
# 143                           Norfolk Terrier            4
# 144                        Norwegian Elkhound            5
# 145                           Norwich Terrier            5
# 146        Nova Scotia Duck Tolling Retriever            5
# 147                      Old English Sheepdog            1
# 148                                Otterhound            1
# 149                                  Papillon           55
# 150                    Parson Russell Terrier           49
# 151         Patterdale Terrier / Fell Terrier           14
# 152                                 Pekingese           74
# 153                      Pembroke Welsh Corgi            9
# 154              Petit Basset Griffon Vendeen           11
# 155                             Pharaoh Hound            9
# 156                          Pit Bull Terrier         6739
# 157                               Plott Hound          238
# 158                                   Pointer          336
# 159                                Pomeranian          245
# 160                                    Poodle          289
# 161                        Portuguese Podengo            4
# 162                             Presa Canario           25
# 163                                       Pug          242
# 164                               Rat Terrier          324
# 165                         Redbone Coonhound           98
# 166                                 Retriever          456
# 167                       Rhodesian Ridgeback           69
# 168                                Rottweiler          493
# 169                              Rough Collie            6
# 170                             Saint Bernard           97
# 171                                    Saluki           19
# 172                                   Samoyed            8
# 173                                Schipperke           20
# 174                                 Schnauzer          190
# 175                          Scottish Terrier           13
# 176                                    Setter           10
# 177                                  Shar-Pei          218
# 178                                 Sheep Dog            2
# 179                                  Shepherd         1815
# 180               Shetland Sheepdog / Sheltie           52
# 181                                 Shiba Inu           52
# 182                                  Shih Tzu          404
# 183                            Siberian Husky          412
# 184                             Silky Terrier           15
# 185                              Skye Terrier            1
# 186                             Smooth Collie            8
# 187                        Smooth Fox Terrier            3
# 188                                   Spaniel          140
# 189                          Spinone Italiano            1
# 190                                     Spitz           30
# 191                Staffordshire Bull Terrier          354
# 192                           Standard Poodle           46
# 193                        Standard Schnauzer            9
# 194                                   Terrier         2378
# 195                            Thai Ridgeback            3
# 196                           Tibetan Mastiff            7
# 197                           Tibetan Spaniel            8
# 198                           Tibetan Terrier            3
# 199                                  Tosa Inu            1
# 200                           Toy Fox Terrier           25
# 201                  Treeing Walker Coonhound          245
# 202                                    Vizsla           58
# 203                                Weimaraner          122
# 204      West Highland White Terrier / Westie           18
# 205                           Wheaten Terrier           18
# 206                                   Whippet           80
# 207                     White German Shepherd           17
# 208                          Wire Fox Terrier           15
# 209                      Wirehaired Dachshund            3
# 210               Wirehaired Pointing Griffon            1
# 211                        Wirehaired Terrier           56
# 212         Xoloitzcuintli / Mexican Hairless           11
# 213                 Yellow Labrador Retriever          158
# 214                         Yorkshire Terrier          345

# %% [markdown]
# **Merging the tables**:

# %%
ratio_mixed = pd.merge(mixed_for_breed, not_mixed_for_breed, on='breed_primary')
ratio_mixed
# Out:
#                             breed_primary  n_mixed  n_not_mixed
# 0                           Affenpinscher        1           16
# 1                        Airedale Terrier        1           18
# 2                                   Akita        6          175
# 3                        Alaskan Malamute        4           68
# 4                        American Bulldog      106         1028
# 5                     American Eskimo Dog        2           41
# 6               American Hairless Terrier        2            2
# 7          American Staffordshire Terrier      110         1752
# 8                      Anatolian Shepherd        9          109
# 9     Australian Cattle Dog / Blue Heeler       72          901
# 10                      Australian Kelpie        9           34
# 11                    Australian Shepherd       24          672
# 12                                Basenji        4           50
# 13                           Basset Hound       14          227
# 14                                 Beagle       80         1459
# 15            Belgian Shepherd / Malinois        7           87
# 16                   Bernese Mountain Dog        1           19
# 17                           Bichon Frise        2           80
# 18               Black Labrador Retriever       13          532
# 19                        Black Mouth Cur       19          182
# 20                Black and Tan Coonhound        7           81
# 21                             Bloodhound        4           50
# 22                     Bluetick Coonhound        4           88
# 23                          Border Collie       50          767
# 24                         Border Terrier        3           25
# 25                                 Borzoi        1            5
# 26                         Boston Terrier        7          142
# 27                                  Boxer      143         1907
# 28                       Brussels Griffon        1           23
# 29                           Bull Terrier       10          166
# 30                            Bullmastiff        3           52
# 31                          Cairn Terrier        6           85
# 32                             Cane Corso        5           78
# 33                   Cardigan Welsh Corgi        5           21
# 34                           Carolina Dog        4           57
# 35                  Catahoula Leopard Dog       30          458
# 36                             Cattle Dog       38          406
# 37               Chesapeake Bay Retriever        1           22
# 38                              Chihuahua      190         3576
# 39           Chocolate Labrador Retriever        1          154
# 40                              Chow Chow       20          145
# 41                         Cocker Spaniel        3          206
# 42                                 Collie       12          224
# 43                              Coonhound       11          275
# 44                                  Corgi        4          124
# 45                              Dachshund       36          817
# 46                              Dalmatian        5           72
# 47                      Doberman Pinscher       11          256
# 48                      Dogue de Bordeaux        4           18
# 49                         Dutch Shepherd        3           60
# 50                        English Bulldog        5          172
# 51                      English Coonhound        5           25
# 52                        English Pointer        1           89
# 53                       English Shepherd        2           18
# 54                            Entlebucher        1            1
# 55                                  Feist        5          134
# 56                  Flat-Coated Retriever        1           42
# 57                            Fox Terrier        4           36
# 58                               Foxhound        4           96
# 59                         French Bulldog        1           45
# 60                        German Pinscher        1            6
# 61                    German Shepherd Dog      189         1933
# 62             German Shorthaired Pointer        5           83
# 63              German Wirehaired Pointer        2            8
# 64                       Golden Retriever        6          197
# 65                          Gordon Setter        1            1
# 66                             Great Dane        5          329
# 67                         Great Pyrenees       11          470
# 68                              Greyhound        6          300
# 69                               Havanese        1           23
# 70                                  Hound      189         2093
# 71                                  Husky       31          536
# 72                          Irish Terrier        1           16
# 73                        Irish Wolfhound        1           16
# 74                      Italian Greyhound        3           63
# 75                   Jack Russell Terrier        5          632
# 76                     Labrador Retriever      616         6582
# 77                      Lancashire Heeler        1            3
# 78                             Lhasa Apso        2           58
# 79                                Maltese        9          174
# 80                     Manchester Terrier        4           35
# 81                                Mastiff       26          275
# 82                    Miniature Dachshund        1            2
# 83                     Miniature Pinscher       28          289
# 84                    Miniature Schnauzer        2           24
# 85                           Mountain Cur        6          162
# 86                       Newfoundland Dog        1           25
# 87                        Norfolk Terrier        1            4
# 88                     Norwegian Elkhound        1            5
# 89                        Norwich Terrier        1            5
# 90                             Otterhound        1            1
# 91                               Papillon        4           55
# 92                 Parson Russell Terrier       21           49
# 93      Patterdale Terrier / Fell Terrier        2           14
# 94                              Pekingese        2           74
# 95           Petit Basset Griffon Vendeen        1           11
# 96                          Pharaoh Hound        2            9
# 97                       Pit Bull Terrier     1151         6739
# 98                            Plott Hound       27          238
# 99                                Pointer       31          336
# 100                            Pomeranian        7          245
# 101                                Poodle       15          289
# 102                         Presa Canario        2           25
# 103                                   Pug       13          242
# 104                           Rat Terrier       14          324
# 105                     Redbone Coonhound        6           98
# 106                             Retriever       82          456
# 107                   Rhodesian Ridgeback        5           69
# 108                            Rottweiler       40          493
# 109                         Saint Bernard        5           97
# 110                            Schipperke        2           20
# 111                             Schnauzer       10          190
# 112                              Shar-Pei       31          218
# 113                             Sheep Dog        1            2
# 114                              Shepherd      157         1815
# 115           Shetland Sheepdog / Sheltie        2           52
# 116                             Shiba Inu        8           52
# 117                              Shih Tzu       17          404
# 118                        Siberian Husky       27          412
# 119                    Smooth Fox Terrier        1            3
# 120                               Spaniel        8          140
# 121                                 Spitz        4           30
# 122            Staffordshire Bull Terrier       36          354
# 123                       Standard Poodle        1           46
# 124                    Standard Schnauzer        5            9
# 125                               Terrier      263         2378
# 126                       Tibetan Mastiff        3            7
# 127                       Tibetan Spaniel        1            8
# 128                       Toy Fox Terrier        1           25
# 129              Treeing Walker Coonhound       13          245
# 130                                Vizsla        2           58
# 131                            Weimaraner        4          122
# 132  West Highland White Terrier / Westie        1           18
# 133                       Wheaten Terrier        1           18
# 134                               Whippet        3           80
# 135                  Wirehaired Dachshund        1            3
# 136                    Wirehaired Terrier        4           56
# 137                     Yorkshire Terrier       15          345

# %% [markdown]
# **Calculating the ratio between 'mixed' and 'not_mixed'**:

# %%
ratio_mixed['ratio_M_notM'] = ratio_mixed['n_mixed']/not_mixed_for_breed['n_not_mixed']
ratio_mixed
# Out:
#                             breed_primary  n_mixed  n_not_mixed  ratio_M_notM
# 0                           Affenpinscher        1           16      0.062500
# 1                        Airedale Terrier        1           18      0.250000
# 2                                   Akita        6          175      0.333333
# 3                        Alaskan Malamute        4           68      1.333333
# 4                        American Bulldog      106         1028      0.605714
# 5                     American Eskimo Dog        2           41      0.029412
# 6               American Hairless Terrier        2            2      0.001946
# 7          American Staffordshire Terrier      110         1752      2.682927
# 8                      Anatolian Shepherd        9          109      0.529412
# 9     Australian Cattle Dog / Blue Heeler       72          901     36.000000
# 10                      Australian Kelpie        9           34      0.005137
# 11                    Australian Shepherd       24          672      0.220183
# 12                                Basenji        4           50      0.004440
# 13                           Basset Hound       14          227      0.411765
# 14                                 Beagle       80         1459      0.119048
# 15            Belgian Shepherd / Malinois        7           87      0.466667
# 16                   Bernese Mountain Dog        1           19      0.020000
# 17                           Bichon Frise        2           80      0.008811
# 18               Black Labrador Retriever       13          532      0.008910
# 19                        Black Mouth Cur       19          182      3.166667
# 20                Black and Tan Coonhound        7           81      1.750000
# 21                             Bloodhound        4           50      4.000000
# 22                     Bluetick Coonhound        4           88      0.045977
# 23                          Border Collie       50          767     16.666667
# 24                         Border Terrier        3           25      1.500000
# 25                                 Borzoi        1            5      0.052632
# 26                         Boston Terrier        7          142      0.087500
# 27                                  Boxer      143         1907      0.268797
# 28                       Brussels Griffon        1           23      0.005495
# 29                           Bull Terrier       10          166      0.123457
# 30                            Bullmastiff        3           52      0.060000
# 31                          Cairn Terrier        6           85      0.461538
# 32                             Cane Corso        5           78      0.056818
# 33                   Cardigan Welsh Corgi        5           21      0.625000
# 34                           Carolina Dog        4           57      4.000000
# 35                  Catahoula Leopard Dog       30          458      0.039113
# 36                             Cattle Dog       38          406      1.520000
# 37               Chesapeake Bay Retriever        1           22      0.200000
# 38                              Chihuahua      190         3576      1.338028
# 39           Chocolate Labrador Retriever        1          154      1.000000
# 40                              Chow Chow       20          145      0.010488
# 41                         Cocker Spaniel        3          206      3.000000
# 42                                 Collie       12          224     12.000000
# 43                              Coonhound       11          275      0.354839
# 44                                  Corgi        4          124      0.173913
# 45                              Dachshund       36          817      0.216867
# 46                              Dalmatian        5           72      0.096154
# 47                      Doberman Pinscher       11          256      0.129412
# 48                      Dogue de Bordeaux        4           18      0.235294
# 49                         Dutch Shepherd        3           60      0.038462
# 50                        English Bulldog        5          172      0.238095
# 51                      English Coonhound        5           25      0.087719
# 52                        English Pointer        1           89      0.002183
# 53                       English Shepherd        2           18      0.004926
# 54                            Entlebucher        1            1      0.333333
# 55                                  Feist        5          134      0.217391
# 56                  Flat-Coated Retriever        1           42      0.045455
# 57                            Fox Terrier        4           36      0.001119
# 58                               Foxhound        4           96      0.222222
# 59                         French Bulldog        1           45      1.000000
# 60                        German Pinscher        1            6      1.000000
# 61                    German Shepherd Dog      189         1933      1.227273
# 62             German Shorthaired Pointer        5           83      0.034483
# 63              German Wirehaired Pointer        2            8      0.500000
# 64                       Golden Retriever        6          197      0.352941
# 65                          Gordon Setter        1            1      0.004854
# 66                             Great Dane        5          329      0.022321
# 67                         Great Pyrenees       11          470      0.040000
# 68                              Greyhound        6          300      0.048387
# 69                               Havanese        1           23      0.500000
# 70                                  Hound      189         2093     94.500000
# 71                                  Husky       31          536      0.037944
# 72                          Irish Terrier        1           16      0.013889
# 73                        Irish Wolfhound        1           16      0.003906
# 74                      Italian Greyhound        3           63      0.088235
# 75                   Jack Russell Terrier        5          632      0.277778
# 76                     Labrador Retriever      616         6582     10.266667
# 77                      Lancashire Heeler        1            3      0.005814
# 78                             Lhasa Apso        2           58      1.000000
# 79                                Maltese        9          174      0.360000
# 80                     Manchester Terrier        4           35      1.000000
# 81                                Mastiff       26          275      0.292135
# 82                    Miniature Dachshund        1            2      0.035714
# 83                     Miniature Pinscher       28          289      1.555556
# 84                    Miniature Schnauzer        2           24      0.057143
# 85                           Mountain Cur        6          162      6.000000
# 86                       Newfoundland Dog        1           25      0.125000
# 87                        Norfolk Terrier        1            4      0.007463
# 88                     Norwegian Elkhound        1            5      1.000000
# 89                        Norwich Terrier        1            5      1.000000
# 90                             Otterhound        1            1      0.200000
# 91                               Papillon        4           55      0.095238
# 92                 Parson Russell Terrier       21           49      0.583333
# 93      Patterdale Terrier / Fell Terrier        2           14      0.020833
# 94                              Pekingese        2           74      0.044444
# 95           Petit Basset Griffon Vendeen        1           11      0.125000
# 96                          Pharaoh Hound        2            9      0.333333
# 97                       Pit Bull Terrier     1151         6739      0.595447
# 98                            Plott Hound       27          238      0.325301
# 99                                Pointer       31          336     15.500000
# 100                            Pomeranian        7          245      0.875000
# 101                                Poodle       15          289      2.500000
# 102                         Presa Canario        2           25      0.010152
# 103                                   Pug       13          242     13.000000
# 104                           Rat Terrier       14          324      0.042553
# 105                     Redbone Coonhound        6           98      0.012766
# 106                             Retriever       82          456     11.714286
# 107                   Rhodesian Ridgeback        5           69      0.016667
# 108                            Rottweiler       40          493      2.857143
# 109                         Saint Bernard        5           97      0.217391
# 110                            Schipperke        2           20      0.000956
# 111                             Schnauzer       10          190      0.018657
# 112                              Shar-Pei       31          218      6.200000
# 113                             Sheep Dog        1            2      0.125000
# 114                              Shepherd      157         1815      9.812500
# 115           Shetland Sheepdog / Sheltie        2           52      0.125000
# 116                             Shiba Inu        8           52      0.126984
# 117                              Shih Tzu       17          404      0.026899
# 118                        Siberian Husky       27          412      1.800000
# 119                    Smooth Fox Terrier        1            3      0.021739
# 120                               Spaniel        8          140      8.000000
# 121                                 Spitz        4           30      1.000000
# 122            Staffordshire Bull Terrier       36          354     36.000000
# 123                       Standard Poodle        1           46      0.500000
# 124                    Standard Schnauzer        5            9      0.000760
# 125                               Terrier      263         2378     52.600000
# 126                       Tibetan Mastiff        3            7      1.000000
# 127                       Tibetan Spaniel        1            8      1.000000
# 128                       Toy Fox Terrier        1           25      0.017241
# 129              Treeing Walker Coonhound       13          245      0.074713
# 130                                Vizsla        2           58      0.057143
# 131                            Weimaraner        4          122      1.000000
# 132  West Highland White Terrier / Westie        1           18      0.003636
# 133                       Wheaten Terrier        1           18      0.200000
# 134                               Whippet        3           80      1.500000
# 135                  Wirehaired Dachshund        1            3      0.003460
# 136                    Wirehaired Terrier        4           56      0.333333
# 137                     Yorkshire Terrier       15          345      0.625000

# %% [markdown]
# **METHOD 2:**
#
# **Considering the 'breed_mixed' column**

# %% [markdown]
# **If True it means that the dog is of mixed breed**

# %%
mixed_breed = dogs_clean.where(dogs_clean['breed_mixed']== True).groupby('breed_primary').size().reset_index(name='mixed')
mixed_breed.head()
# Out:
#       breed_primary  mixed
# 0     Affenpinscher      5
# 1      Afghan Hound      4
# 2  Airedale Terrier     17
# 3            Akbash      2
# 4             Akita     83

# %% [markdown]
# **If False it means that the dog is not of mixed breed**

# %%
not_mixed_breed = dogs.where(dogs['breed_mixed'] == False).groupby('breed_primary').size().reset_index(name='not_mixed')
not_mixed_breed.head()
# Out:
#       breed_primary  not_mixed
# 0     Affenpinscher         12
# 1  Airedale Terrier          2
# 2            Akbash          1
# 3             Akita         98
# 4  Alaskan Malamute         52

# %% [markdown]
# **We merge and calculate the ratio**

# %%
breed_ratio = pd.merge(mixed_breed, not_mixed_breed, on='breed_primary')
breed_ratio.head()
# Out:
#       breed_primary  mixed  not_mixed
# 0     Affenpinscher      5         12
# 1  Airedale Terrier     17          2
# 2            Akbash      2          1
# 3             Akita     83         98
# 4  Alaskan Malamute     20         52

# %%
breed_ratio['ratio'] = breed_ratio['mixed'] / breed_ratio['not_mixed']
breed_ratio.head()
# Out:
#       breed_primary  mixed  not_mixed     ratio
# 0     Affenpinscher      5         12  0.416667
# 1  Airedale Terrier     17          2  8.500000
# 2            Akbash      2          1  2.000000
# 3             Akita     83         98  0.846939
# 4  Alaskan Malamute     20         52  0.384615

# %% [markdown]
# # 4. For each (primary) breed, determine the earliest and the latest posted timestamp.

# %% [markdown]
# **We check and convert the 'posted' type to datetime**

# %%
print(dogs_clean['posted'].dtypes)
# Out:
# object

# %%
dogs_clean['posted'] = pd.to_datetime(dogs_clean['posted'])

# %%
dogs_clean.dropna(subset=['posted'], inplace=True)
len(dogs_clean)
# Out:
# 58180

# %%
print(dogs_clean['posted'].dtypes)
# Out:
# datetime64[ns, UTC]

# %% [markdown]
# **We find the min and the max for each 'breed_primary' and merge them in a single table**

# %%
earliest_timestamps = dogs_clean.groupby(by='breed_primary')['posted'].min().reset_index()
latest_timestamps = dogs_clean.groupby(by='breed_primary')['posted'].max().reset_index()

# %%
timestamps = pd.merge(earliest_timestamps, latest_timestamps, on="breed_primary").rename(columns={'posted_x':'earliest_timestamp', 'posted_y':'latest_timestamp'})
timestamps.head()
# Out:
#       breed_primary        earliest_timestamp          latest_timestamp
# 0     Affenpinscher 2012-03-08 10:27:33+00:00 2019-09-14 10:10:51+00:00
# 1      Afghan Hound 2017-06-29 23:28:51+00:00 2019-07-27 00:38:48+00:00
# 2  Airedale Terrier 2014-06-13 12:59:36+00:00 2019-09-19 18:40:39+00:00
# 3            Akbash 2019-07-21 00:35:59+00:00 2019-08-23 17:11:04+00:00
# 4             Akita 2012-03-03 09:31:08+00:00 2019-09-20 15:19:57+00:00

# %% [markdown]
# # 5. For each state, compute the sex imbalance, that is the difference between male and female dogs. In which state this imbalance is largest?

# %% [markdown]
# **We count the values of Females and Males for each State and then calculate the sex imbalance**

# %%
sex_counts = dogs_clean.groupby('contact_state')['sex'].value_counts().unstack()
sex_counts.head()
# Out:
# sex            Female    Male  Unknown
# contact_state
# AK                7.0     8.0      NaN
# AL              716.0   712.0      NaN
# AR              351.0   344.0      NaN
# AZ             1067.0  1181.0      1.0
# CA              777.0   887.0      NaN

# %%
sex_counts['sex_imbalance'] = sex_counts['Male'] - sex_counts['Female']
sex_counts.head()
# Out:
# sex            Female    Male  Unknown  sex_imbalance
# contact_state
# AK                7.0     8.0      NaN            1.0
# AL              716.0   712.0      NaN           -4.0
# AR              351.0   344.0      NaN           -7.0
# AZ             1067.0  1181.0      1.0          114.0
# CA              777.0   887.0      NaN          110.0

# %% [markdown]
# **Using the 'states' df, we find the full name of the state with the largest sex imbalance, through the 'abbreviation' column**

# %%
max_imbalance_state = sex_counts['sex_imbalance'].idxmax()
max_imbalance_state_name = states.loc[states['abbreviation'] == max_imbalance_state].values[0][0]
print(f'The state with the largest sex imbalance is: {max_imbalance_state_name}')
# Out:
# The state with the largest sex imbalance is: Ohio

# %% [markdown]
# # 6. For each pair (age, size), determine the average duration of the stay and the average cost of stay.

# %%
mean_stay_cost = dogs_clean.groupby(['age', 'size'], as_index=False)[['age','size','stay_duration','stay_cost']].mean(['stay_duration','stay_cost'])
mean_stay_cost
# Out:
#        age         size  stay_duration   stay_cost
# 0    Adult  Extra Large      89.015414  232.591561
# 1    Adult        Large      89.531943  238.661141
# 2    Adult       Medium      89.421036  238.258977
# 3    Adult        Small      89.407479  238.974838
# 4     Baby  Extra Large      87.032967  237.180879
# 5     Baby        Large      89.701564  238.698827
# 6     Baby       Medium      89.577668  237.108131
# 7     Baby        Small      89.958291  239.083810
# 8   Senior  Extra Large      88.861111  235.232361
# 9   Senior        Large      88.984298  237.507364
# 10  Senior       Medium      89.810052  238.514615
# 11  Senior        Small      89.073626  238.282286
# 12   Young  Extra Large      90.586345  245.835582
# 13   Young        Large      90.104206  238.149506
# 14   Young       Medium      89.515123  239.304603
# 15   Young        Small      89.814275  241.540069

# %% [markdown]
# **Apply a categorization to the values contained in the 'age' column:**

# %%
mean_stay_cost['age'] = pd.Categorical(mean_stay_cost['age'], 
                                       categories=['Baby', 'Young', 'Adult', 'Senior'],
                                       ordered=True
                                      )

mean_stay_cost['size'] = pd.Categorical(mean_stay_cost['size'], 
                                        categories = ['Small', 'Medium', 'Large', 'Extra Large'],
                                        ordered=True
                                       )

# %% [markdown]
# **Renaming the columns:**

# %%
mean_stay_cost.rename(columns={"stay_duration": "mean_stay_duration", "stay_cost": "mean_stay_cost"}, inplace=True)

# %%
mean_stay_cost.groupby(by=['age', 'size'])[['mean_stay_duration', 'mean_stay_cost']].mean() 
#use 'age' and 'size' as index and sorting to show the results
# Out:
#                     mean_stay_duration  mean_stay_cost
# age    size
# Baby   Small                 89.958291      239.083810
#        Medium                89.577668      237.108131
#        Large                 89.701564      238.698827
#        Extra Large           87.032967      237.180879
# Young  Small                 89.814275      241.540069
#        Medium                89.515123      239.304603
#        Large                 90.104206      238.149506
#        Extra Large           90.586345      245.835582
# Adult  Small                 89.407479      238.974838
#        Medium                89.421036      238.258977
#        Large                 89.531943      238.661141
#        Extra Large           89.015414      232.591561
# Senior Small                 89.073626      238.282286
#        Medium                89.810052      238.514615
#        Large                 88.984298      237.507364
#        Extra Large           88.861111      235.232361

# %% [markdown]
# # 7. Find the dogs involved in at least 3 travels. Also list the breed of those dogs.

# %%
dog_travel.head()
# Out:
#    index        id contact_city contact_state  \
# 0      0  44520267        Anoka            MN
# 1      1  44698509    Groveland            FL
# 2      2  45983838    Adamstown            MD
# 3      3  44475904  Saint Cloud            MN
# 4      4  43877389       Pueblo            CO
#
#                                          description        found    manual  \
# 0  Boris is a handsome mini schnauzer who made hi...     Arkansas       NaN
# 1  Duke is an almost 2 year old Potcake from Abac...       Abacos   Bahamas
# 2  Zac Woof-ron is a heartthrob movie star lookin...         Adam  Maryland
# 3  ~~Came in to the shelter as a transfer from an...      Adaptil       NaN
# 4  Palang is such a sweetheart. She loves her peo...  Afghanistan       NaN
#
#   remove still_there
# 0    NaN         NaN
# 1    NaN         NaN
# 2    NaN         NaN
# 3   True         NaN
# 4    NaN         NaN

# %% [markdown]
# **We count the number of travels for each 'id' and select only the ones >= 3**

# %%
n_viaggi = dog_travel.groupby('id').count()
n_viaggi.rename(columns={'index' : 'n_travels'}, inplace=True)
n_viaggi = n_viaggi[['n_travels']]
n_viaggi.head()
# Out:
#           n_travels
# id
# 8619716           2
# 9317153           1
# 12134429          1
# 14355301          1
# 16313278          1

# %%
n_viaggi = n_viaggi[n_viaggi['n_travels'] >= 3]
n_viaggi.head()
# Out:
#           n_travels
# id
# 16657005          4
# 20905974          5
# 24894870          4
# 24894894          4
# 33218331          7

# %% [markdown]
# **Merging with the 'dogs_clean' df, we can find the 'breed_primary'**

# %%
atleast_3 = pd.merge(n_viaggi, dogs_clean, on='id')
atleast_3[['id', 'n_travels', 'breed_primary']].head()
# Out:
#          id  n_travels     breed_primary
# 0  16657005          4  Pit Bull Terrier
# 1  20905974          5         Chow Chow
# 2  24894870          4             Hound
# 3  24894894          4             Hound
# 4  33218331          7  Alaskan Malamute

# %%
len(atleast_3)
# Out:
# 563

# %% [markdown]
# # 8. Fix the travels table so that the correct state is computed from the manual and the found fields. If manual is not missing, then it overrides what is stored in found.

# %%
dog_travel.head()
# Out:
#    index        id contact_city contact_state  \
# 0      0  44520267        Anoka            MN
# 1      1  44698509    Groveland            FL
# 2      2  45983838    Adamstown            MD
# 3      3  44475904  Saint Cloud            MN
# 4      4  43877389       Pueblo            CO
#
#                                          description        found    manual  \
# 0  Boris is a handsome mini schnauzer who made hi...     Arkansas       NaN
# 1  Duke is an almost 2 year old Potcake from Abac...       Abacos   Bahamas
# 2  Zac Woof-ron is a heartthrob movie star lookin...         Adam  Maryland
# 3  ~~Came in to the shelter as a transfer from an...      Adaptil       NaN
# 4  Palang is such a sweetheart. She loves her peo...  Afghanistan       NaN
#
#   remove still_there
# 0    NaN         NaN
# 1    NaN         NaN
# 2    NaN         NaN
# 3   True         NaN
# 4    NaN         NaN

# %%
"""
The function takes two strings in input 'found' and 'manual'
and returns 'found' if 'manual' is Null
returns 'manual' otherwise
"""
def correct_state(found, manual):
    if pd.isna(manual):
        return found
    else:
        return manual

# %% [markdown]
# **Apply the above function to every row of the 'dog_travel' dataframe using the lambda row sintax and storing the result in a list called 'lista'**

# %%
lista = dog_travel.apply(lambda row: correct_state(row['found'], row['manual']), axis=1)
lista
# Out:
# 0          Arkansas
# 1           Bahamas
# 2          Maryland
# 3           Adaptil
# 4       Afghanistan
#            ...
# 6189             WV
# 6190        Wyoming
# 6191         Yazmin
# 6192           Ohio
# 6193           Zazu
# Length: 6194, dtype: object

# %% [markdown]
# **Replacing the values in 'lista'**

# %%
dog_travel['found'] = lista
dog_travel.head()
# Out:
#    index        id contact_city contact_state  \
# 0      0  44520267        Anoka            MN
# 1      1  44698509    Groveland            FL
# 2      2  45983838    Adamstown            MD
# 3      3  44475904  Saint Cloud            MN
# 4      4  43877389       Pueblo            CO
#
#                                          description        found    manual  \
# 0  Boris is a handsome mini schnauzer who made hi...     Arkansas       NaN
# 1  Duke is an almost 2 year old Potcake from Abac...      Bahamas   Bahamas
# 2  Zac Woof-ron is a heartthrob movie star lookin...     Maryland  Maryland
# 3  ~~Came in to the shelter as a transfer from an...      Adaptil       NaN
# 4  Palang is such a sweetheart. She loves her peo...  Afghanistan       NaN
#
#   remove still_there
# 0    NaN         NaN
# 1    NaN         NaN
# 2    NaN         NaN
# 3   True         NaN
# 4    NaN         NaN

# %% [markdown]
# # 9. For each state, compute the ratio between the number of travels and the population.

# %%
dog_travel.head()
# Out:
#    index        id contact_city contact_state  \
# 0      0  44520267        Anoka            MN
# 1      1  44698509    Groveland            FL
# 2      2  45983838    Adamstown            MD
# 3      3  44475904  Saint Cloud            MN
# 4      4  43877389       Pueblo            CO
#
#                                          description        found    manual  \
# 0  Boris is a handsome mini schnauzer who made hi...     Arkansas       NaN
# 1  Duke is an almost 2 year old Potcake from Abac...      Bahamas   Bahamas
# 2  Zac Woof-ron is a heartthrob movie star lookin...     Maryland  Maryland
# 3  ~~Came in to the shelter as a transfer from an...      Adaptil       NaN
# 4  Palang is such a sweetheart. She loves her peo...  Afghanistan       NaN
#
#   remove still_there
# 0    NaN         NaN
# 1    NaN         NaN
# 2    NaN         NaN
# 3   True         NaN
# 4    NaN         NaN

# %% [markdown]
# **We merge the 'NST_EST' df and the 'states' df to have a complete df with 'abbreviation', 'state', 'population'**

# %%
NST = pd.merge(NST_EST, states, on='state')
NST[['abbreviation', 'state', 'population']].head()
# Out:
#   abbreviation       state  population
# 0           AL     Alabama     5024279
# 1           AK      Alaska      733391
# 2           AZ     Arizona     7151502
# 3           AR    Arkansas     3011524
# 4           CA  California    39538223

# %% [markdown]
# **We count the number of travels for each state**

# %%
travels_count = dog_travel.groupby('contact_state').size().reset_index(name='travels')
travels_count.head()
# Out:
#   contact_state  travels
# 0         17325       10
# 1            AL       75
# 2            AR       10
# 3            AZ       70
# 4            CA       28

# %% [markdown]
# **We notice that '17325' correspond to the zip code of Pennsylvania (PA), so we replace it and run the count again**

# %%
dog_travel['contact_state'].replace('17325', 'PA', inplace=True)

# %%
travels_count = dog_travel.groupby('contact_state').size().reset_index(name='travels')
travels_count
# Out:
#    contact_state  travels
# 0             AL       75
# 1             AR       10
# 2             AZ       70
# 3             CA       28
# 4             CO      103
# 5             CT       90
# 6             DC      112
# 7             DE       57
# 8             FL      133
# 9             GA      109
# 10            IA       22
# 11            IL       37
# 12            IN       65
# 13            KS        3
# 14            KY       31
# 15            LA        5
# 16            MA      107
# 17            MD      379
# 18            ME      361
# 19            MI       67
# 20            MN      190
# 21            MO       42
# 22            MS        6
# 23            NB        2
# 24            NC      187
# 25            NH       44
# 26            NJ      552
# 27            NM       82
# 28            NV       20
# 29            NY      490
# 30            OH      177
# 31            OK       31
# 32            OR       32
# 33            PA      326
# 34            RI      130
# 35            SC       21
# 36            TN      112
# 37            TX        2
# 38            UT       66
# 39            VA     1025
# 40            VT       49
# 41            WA      634
# 42            WI       83
# 43            WV       27

# %% [markdown]
# **We merge as to have a df with 'contact_state', 'population', 'travels' so now we can calculate the ratio in a new column**

# %%
state_ratio = pd.merge(NST, travels_count, left_on='abbreviation', right_on='contact_state')[['contact_state','population', 'travels']]
state_ratio.head()
# Out:
#   contact_state  population  travels
# 0            AL     5024279       75
# 1            AZ     7151502       70
# 2            AR     3011524       10
# 3            CA    39538223       28
# 4            CO     5773714      103

# %%
state_ratio['ratio'] = state_ratio['travels'] / state_ratio['population']
state_ratio.rename(columns = {'contact_state' : 'state'}, inplace = True)
state_ratio.head()
# Out:
#   state  population  travels         ratio
# 0    AL     5024279       75  1.492751e-05
# 1    AZ     7151502       70  9.788154e-06
# 2    AR     3011524       10  3.320578e-06
# 3    CA    39538223       28  7.081755e-07
# 4    CO     5773714      103  1.783947e-05

# %% [markdown]
# # 10. For each dog, compute the number of days from the posted day to the day of last access.

# %% [markdown]
# **Control data types of 'posted' and 'accessed' columns and changing them to 'datetime' if they are not**

# %%
print(dogs_clean['posted'].dtypes)
# Out:
# datetime64[ns, UTC]

# %%
print(dogs_clean['accessed'].dtypes)
# Out:
# object

# %%
dogs_clean['accessed'] = pd.to_datetime(dogs_clean['accessed'], errors = 'coerce')

# %%
dogs.dropna(subset=['accessed'], inplace=True)
len(dogs_clean)
# Out:
# 58180

# %%
print(dogs_clean['posted'].dtypes)
# Out:
# datetime64[ns, UTC]

# %%
print(dogs_clean['accessed'].dtypes)
# Out:
# datetime64[ns]

# %% [markdown]
# **Converting from a 'datetime' to a 'date'**

# %%
dogs_clean['posted'] = dogs_clean['posted'].dt.date

# %%
dogs_clean['accessed'] = dogs_clean['accessed'].dt.date

# %% [markdown]
# **Calculating the days between 'posted' and 'accessed'**

# %%
dogs_clean['days_between'] = (dogs_clean['accessed'] - dogs_clean['posted']).dt.days

# %%
days_between = dogs_clean[['id', 'posted', 'accessed', 'days_between']]
days_between
# Out:
#              id      posted    accessed  days_between
# 0      46042150  2019-09-20  2019-09-20             0
# 1      46042002  2019-09-20  2019-09-20             0
# 2      46040898  2019-09-20  2019-09-20             0
# 3      46039877  2019-09-20  2019-09-20             0
# 4      46039306  2019-09-20  2019-09-20             0
# ...         ...         ...         ...           ...
# 58175  44605893  2019-05-03  2019-09-20           140
# 58176  44457061  2019-04-13  2019-09-20           160
# 58177  42865848  2018-09-27  2019-09-20           358
# 58178  42734734  2018-09-12  2019-09-20           373
# 58179  42663515  2018-09-03  2019-09-20           382
#
# [58180 rows x 4 columns]

# %% [markdown]
# # 11. Partition the dogs according to the number of weeks from the posted day to the day of last access.

# %% [markdown]
# **We devide the days that have passed by 7, as to have the number of weeks**

# %%
dogs_clean['weeks_between'] = (dogs_clean['accessed'] - dogs_clean['posted']).dt.days/7
dogs_clean['weeks_between'] = dogs_clean['weeks_between'].round(2)

# %% [markdown]
# **We then bin the number of weeks into pre-defined ranges, and save to a new column**

# %%
dogs_clean['weeks_range'] = pd.cut(dogs_clean['weeks_between'], bins=[-np.inf, 1, 4, 8, 12, 16, 24, 25, 52, np.inf], labels=['< 1 week', '1-4 weeks', '4-8 weeks', '8-12 weeks', '12-16 weeks', '16 weeks - 6 months', '> 6 months', '1 year', '> 1 year'])

# %%
weeks_between = dogs_clean[['id', 'posted', 'accessed', 'days_between', 'weeks_between', 'weeks_range']]
weeks_between
# Out:
#              id      posted    accessed  days_between  weeks_between  \
# 0      46042150  2019-09-20  2019-09-20             0           0.00
# 1      46042002  2019-09-20  2019-09-20             0           0.00
# 2      46040898  2019-09-20  2019-09-20             0           0.00
# 3      46039877  2019-09-20  2019-09-20             0           0.00
# 4      46039306  2019-09-20  2019-09-20             0           0.00
# ...         ...         ...         ...           ...            ...
# 58175  44605893  2019-05-03  2019-09-20           140          20.00
# 58176  44457061  2019-04-13  2019-09-20           160          22.86
# 58177  42865848  2018-09-27  2019-09-20           358          51.14
# 58178  42734734  2018-09-12  2019-09-20           373          53.29
# 58179  42663515  2018-09-03  2019-09-20           382          54.57
#
#                weeks_range
# 0                 < 1 week
# 1                 < 1 week
# 2                 < 1 week
# 3                 < 1 week
# 4                 < 1 week
# ...                    ...
# 58175  16 weeks - 6 months
# 58176  16 weeks - 6 months
# 58177               1 year
# 58178             > 1 year
# 58179             > 1 year
#
# [58180 rows x 6 columns]

# %% [markdown]
# # 12. Find for duplicates in the dogs dataset. Two records are duplicates if they have (1) same breeds and sex, and (2) they share at least 90% of the words in the description field. Extra points if you find and implement a more refined for determining if two rows are duplicates.

# %%
# Drop any rows with missing values
dogs_sub = dogs_clean.dropna(subset=['breed_primary', 'description', 'sex'])
dogs_sub
# Out:
#              id org_id                                                url  \
# 0      46042150  NV163  https://www.petfinder.com/dog/harley-46042150/...
# 1      46042002  NV163  https://www.petfinder.com/dog/biggie-46042002/...
# 2      46040898   NV99  https://www.petfinder.com/dog/ziggy-46040898/n...
# 4      46039306  NV184  https://www.petfinder.com/dog/theo-46039306/nv...
# 5      46039304  NV184  https://www.petfinder.com/dog/oliver-46039304/...
# ...         ...    ...                                                ...
# 58166  45168741   WY24  https://www.petfinder.com/dog/charlie-45168741...
# 58167  44843897   WY24  https://www.petfinder.com/dog/samson-44843897/...
# 58172  44658860   WY24  https://www.petfinder.com/dog/buddy-44658860/w...
# 58175  44605893   WY20  https://www.petfinder.com/dog/tren-44605893/wy...
# 58177  42865848   WY20  https://www.petfinder.com/dog/echo-42865848/wy...
#
#       type.x species                   breed_primary  \
# 0        Dog     Dog  American Staffordshire Terrier
# 1        Dog     Dog                Pit Bull Terrier
# 2        Dog     Dog                        Shepherd
# 4        Dog     Dog                       Dachshund
# 5        Dog     Dog                           Boxer
# ...      ...     ...                             ...
# 58166    Dog     Dog             Australian Shepherd
# 58167    Dog     Dog                Pit Bull Terrier
# 58172    Dog     Dog                Pit Bull Terrier
# 58175    Dog     Dog                   Border Collie
# 58177    Dog     Dog                   Border Collie
#
#                            breed_secondary  breed_mixed  breed_unknown  \
# 0                              Mixed Breed         True          False
# 1                              Mixed Breed         True          False
# 2                                      NaN        False          False
# 4                                      NaN        False          False
# 5                                   Beagle         True          False
# ...                                    ...          ...            ...
# 58166  Australian Cattle Dog / Blue Heeler         True          False
# 58167                                  NaN        False          False
# 58172                          Mixed Breed         True          False
# 58175                                  NaN        False          False
# 58177                                  NaN        False          False
#
#                           color_primary              color_secondary  \
# 0                         White / Cream  Yellow / Tan / Blond / Fawn
# 1                     Brown / Chocolate                White / Cream
# 2                               Brindle                          NaN
# 4                                   NaN                          NaN
# 5                                   NaN                          NaN
# ...                                 ...                          ...
# 58166                               NaN                          NaN
# 58167                               NaN                          NaN
# 58172                               NaN                          NaN
# 58175  Tricolor (Brown, Black, & White)                          NaN
# 58177                               NaN                          NaN
#
#       color_tertiary     age     sex    size    coat  fixed  house_trained  \
# 0                NaN  Senior    Male  Medium   Short   True           True
# 1                NaN   Adult    Male   Large   Short   True           True
# 2                NaN   Adult    Male   Large   Short   True          False
# 4                NaN   Young    Male   Small    Long   True          False
# 5                NaN    Baby    Male  Medium   Short   True          False
# ...              ...     ...     ...     ...     ...    ...            ...
# 58166            NaN   Adult    Male  Medium     NaN   True          False
# 58167            NaN   Adult    Male   Large     NaN   True          False
# 58172            NaN    Baby    Male  Medium     NaN   True           True
# 58175            NaN   Adult    Male  Medium  Medium   True           True
# 58177            NaN   Adult  Female  Medium  Medium   True           True
#
#        declawed  special_needs  shots_current env_children env_dogs env_cats  \
# 0           NaN          False           True          NaN      NaN      NaN
# 1           NaN          False           True          NaN      NaN      NaN
# 2           NaN          False           True          NaN      NaN      NaN
# 4           NaN          False           True         True     True     True
# 5           NaN          False           True         True     True     True
# ...         ...            ...            ...          ...      ...      ...
# 58166       NaN          False          False         True     True     True
# 58167       NaN          False          False         True     True     True
# 58172       NaN          False          False         True     True     True
# 58175       NaN          False          False          NaN      NaN      NaN
# 58177       NaN          False           True          NaN      NaN      NaN
#
#           name     status      posted contact_city contact_state contact_zip  \
# 0       HARLEY  adoptable  2019-09-20    Las Vegas            NV       89147
# 1       BIGGIE  adoptable  2019-09-20    Las Vegas            NV       89147
# 2        Ziggy  adoptable  2019-09-20     Mesquite            NV       89027
# 4         Theo  adoptable  2019-09-20    Henderson            NV       89052
# 5       Oliver  adoptable  2019-09-20    Henderson            NV       89052
# ...        ...        ...         ...          ...           ...         ...
# 58166  Charlie  adoptable  2019-07-04     Riverton            WY       82501
# 58167   Samson  adoptable  2019-05-31     Riverton            WY       82501
# 58172    Buddy  adoptable  2019-05-10     Riverton            WY       82501
# 58175     Tren  adoptable  2019-05-03       Lander            WY       82520
# 58177     Echo  adoptable  2018-09-27     Glenrock            WY       82637
#
#       contact_country stateQ    accessed type.y  \
# 0                  US  89009  2019-09-20    Dog
# 1                  US  89009  2019-09-20    Dog
# 2                  US  89009  2019-09-20    Dog
# 4                  US  89009  2019-09-20    Dog
# 5                  US  89009  2019-09-20    Dog
# ...               ...    ...         ...    ...
# 58166              US     WY  2019-09-20    Dog
# 58167              US     WY  2019-09-20    Dog
# 58172              US     WY  2019-09-20    Dog
# 58175              US     WY  2019-09-20    Dog
# 58177              US     WY  2019-09-20    Dog
#
#                                              description  stay_duration  \
# 0      Harley is not sure how he wound up at shelter ...             70
# 1      6 year old Biggie has lost his home and really...             49
# 2      Approx 2 years old.\n Did I catch your eye? I ...             87
# 4      Theo is a friendly dachshund mix who gets alon...             93
# 5      Oliver was born around mid-June and came to us...             70
# ...                                                  ...            ...
# 58166  Charlie was adopted from us 5 years ago, but r...            109
# 58167  Samson is a dog that will need someone to show...             74
# 58172  Buddy was an owner surrender by an older gentl...            135
# 58175  Due to the small size of our volunteer base, w...            100
# 58177  Due to the small size of our volunteer base, w...            100
#
#        stay_cost  days_between  weeks_between          weeks_range
# 0         124.81             0           0.00             < 1 week
# 1         122.07             0           0.00             < 1 week
# 2         281.51             0           0.00             < 1 week
# 4         241.09             0           0.00             < 1 week
# 5          97.77             0           0.00             < 1 week
# ...          ...           ...            ...                  ...
# 58166     280.51            78          11.14           8-12 weeks
# 58167     132.32           112          16.00          12-16 weeks
# 58172     357.97           133          19.00  16 weeks - 6 months
# 58175     324.34           140          20.00  16 weeks - 6 months
# 58177     184.06           358          51.14               1 year
#
# [49475 rows x 40 columns]

# %%
# Preprocess the description field
def preprocess_description(desc):
    if pd.isna(desc):
        return []
    desc = re.sub(r'\W+', ' ', desc.lower())
    return desc.split()

# %% [markdown]
# ^ this function takes a string as input and returns a list of preprocessed words. The preprocessing steps include converting the string to lowercase, removing any non-alphanumeric characters, and splitting the string into a list of words.

# %%
# Define a function to calculate the percentage of shared words between two descriptions

def shared_word_percentage(desc1, desc2):
    set1 = set(desc1)
    set2 = set(desc2)
    if len(set1) == 0 or len(set2) == 0:
        return 0.0
    intersection = set1.intersection(set2)
    union = set1.union(set2)
    return len(intersection) / len(union)

# %% [markdown]
# ^ this function is defined to calculate the percentage of shared words between two descriptions. This is done by first converting the descriptions to sets of words, and then calculating the intersection and union of the sets.

# %%
dogs_sub.loc[:, 'description_processed'] = dogs_sub['description'].apply(preprocess_description)
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_7248\3402708723.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dogs_sub.loc[:, 'description_processed'] = dogs_sub['description'].apply(preprocess_description)

# %% [markdown]
# ^ the 'description_processed' column in the dogs_clean DataFrame is created by applying the 'preprocess_description' function to the 'description' column using the 'apply()' method.

# %%
# Create a dictionary to store the processed descriptions and their corresponding IDs
desc_dict = dict(zip(dogs_sub['id'], dogs_sub['description_processed']))
#desc_dict

# %% [markdown]
# ^ a dictionary called 'desc_dict' is created to store the processed descriptions and their corresponding IDs.

# %%
# Use a hash table to store the processed descriptions and their corresponding IDs
desc_hash = {}
for i, desc in enumerate(dogs_sub['description_processed']):
    desc_hash[hash(' '.join(desc))] = desc_hash.get(hash(' '.join(desc)), []) + [dogs_sub.iloc[i]['id']]

# %% [markdown]
# ^ a hash table called 'desc_hash' is created to store the processed descriptions and their corresponding IDs. The hash table is constructed by iterating over the 'description_processed' column in the dogs_sub DataFrame, and using the 'hash()' function to generate a hash value for each description. The hash value is used as a key in the desc_hash dictionary, and the corresponding ID is added to a list of IDs associated with that hash value.

# %%
# Find the duplicate pairs using the hash table
duplicate_pairs = []
for i, desc in enumerate(dogs_sub['description_processed']):
    desc_hash[hash(' '.join(desc))].remove(dogs_sub.iloc[i]['id'])
    for j in desc_hash[hash(' '.join(desc))]:
        if dogs_sub.iloc[i]['breed_primary'] == dogs_sub[dogs_sub['id'] == j]['breed_primary'].values[0] and \
           dogs_sub.iloc[i]['breed_secondary'] == dogs_sub[dogs_sub['id'] == j]['breed_secondary'].values[0] and \
           dogs_sub.iloc[i]['sex'] == dogs_sub[dogs_sub['id'] == j]['sex'].values[0]:
            shared_words = shared_word_percentage(desc, desc_dict[j])
            if shared_words >= 0.9:
                duplicate_pairs.append((dogs_sub.iloc[i]['id'], j))
    desc_hash[hash(' '.join(desc))].append(dogs_sub.iloc[i]['id'])

# %% [markdown]
# ^ a loop is used to iterate over the 'description_processed' column in the dogs_sub DataFrame. For each record, the ID is removed from the list of IDs associated with its hash value in the desc_hash dictionary. Then, a nested loop is used to compare the current record to all other records in the desc_hash dictionary with the same hash value. If the current record and another record have the same breeds and sex, and their shared word percentage is at least 90%, then they are considered a duplicate pair and their IDs are added to the duplicate_pairs list.
#
# ^^ execution time: ~ 1 minute

# %% [markdown]
# **We save the pairs in a new df and populate with the corresponding values**

# %%
df_duplicate_pairs = pd.DataFrame(duplicate_pairs, columns=['id_1', 'id_2'])
df_duplicate_pairs.head()
# Out:
#        id_1      id_2
# 0  45901985  45901991
# 1  45901985  45901992
# 2  45901985  45901994
# 3  45901985  45901995
# 4  45901985  45901993

# %%
pd.set_option('display.max_colwidth', None)
pd.options.display.max_columns = 40

# %%
dogs_sub[dogs_sub['id'] == 44696946][['id', 'breed_primary', 'breed_secondary', 'sex', 'description']]
# Out:
#              id     breed_primary breed_secondary   sex        description
# 57893  44696946  Pit Bull Terrier           Hound  Male  Color:black/white

# %%
dogs_sub[dogs_sub['id'] == 45301676][['id', 'breed_primary', 'breed_secondary', 'sex', 'description']]
# Out:
#              id     breed_primary breed_secondary   sex        description
# 57779  45301676  Pit Bull Terrier           Hound  Male  Color:black/white

# %%
# Merge 'df_duplicate_pairs' with 'dogs' to populate it with the corresponding values
df_duplicate_pairs = pd.merge(df_duplicate_pairs, dogs, left_on='id_1', right_on='id')
df_duplicate_pairs = df_duplicate_pairs[['id_1', 'id_2', 'breed_primary', 'breed_secondary', 'sex', 'description']]
df_duplicate_pairs = pd.merge(df_duplicate_pairs, dogs, suffixes=['_1', '_2'], left_on='id_2', right_on='id')
df_duplicate_pairs = df_duplicate_pairs[['id_1', 'id_2', 'breed_primary_1', 'breed_primary_2', 'breed_secondary_1', 'breed_secondary_2', 'sex_1', 'sex_2', 'description_1', 'description_2']]

# Print the resulting DataFrame
df_duplicate_pairs.head()
# Out:
#        id_1      id_2 breed_primary_1 breed_primary_2 breed_secondary_1  \
# 0  45901985  45901991          Collie          Collie          Shepherd
# 1  45901992  45901991          Collie          Collie          Shepherd
# 2  45901994  45901991          Collie          Collie          Shepherd
# 3  45901995  45901991          Collie          Collie          Shepherd
# 4  45901993  45901991          Collie          Collie          Shepherd
#
#   breed_secondary_2 sex_1 sex_2  \
# 0          Shepherd  Male  Male
# 1          Shepherd  Male  Male
# 2          Shepherd  Male  Male
# 3          Shepherd  Male  Male
# 4          Shepherd  Male  Male
#
#                                                                                                                                                            description_1  \
# 0  On hold until 9/27 when second set of shots are given. $50 deposit can hold. Non-refundable deposit can be made by going to www.NevadaPaws.org and following the link
# 1  On hold until 9/27 when second set of shots are given. $50 deposit can hold. Non-refundable deposit can be made by going to www.NevadaPaws.org and following the link
# 2  On hold until 9/27 when second set of shots are given. $50 deposit can hold. Non-refundable deposit can be made by going to www.NevadaPaws.org and following the link
# 3  On hold until 9/27 when second set of shots are given. $50 deposit can hold. Non-refundable deposit can be made by going to www.NevadaPaws.org and following the link
# 4  On hold until 9/27 when second set of shots are given. $50 deposit can hold. Non-refundable deposit can be made by going to www.NevadaPaws.org and following the link
#
#                                                                                                                                                            description_2
# 0  On hold until 9/27 when second set of shots are given. $50 deposit can hold. Non-refundable deposit can be made by going to www.NevadaPaws.org and following the link
# 1  On hold until 9/27 when second set of shots are given. $50 deposit can hold. Non-refundable deposit can be made by going to www.NevadaPaws.org and following the link
# 2  On hold until 9/27 when second set of shots are given. $50 deposit can hold. Non-refundable deposit can be made by going to www.NevadaPaws.org and following the link
# 3  On hold until 9/27 when second set of shots are given. $50 deposit can hold. Non-refundable deposit can be made by going to www.NevadaPaws.org and following the link
# 4  On hold until 9/27 when second set of shots are given. $50 deposit can hold. Non-refundable deposit can be made by going to www.NevadaPaws.org and following the link
